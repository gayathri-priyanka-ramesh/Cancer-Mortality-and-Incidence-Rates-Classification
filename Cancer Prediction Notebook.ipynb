# %% [markdown]
# # Importing Libraries

# %%
# Data Science
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Exploratory Data Analysis
from scipy.stats import chi2_contingency
from scipy import stats
from factor_analyzer import FactorAnalyzer

# Data Pre-processing
from scipy.stats.mstats import winsorize
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Model Building
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
import xgboost as xgb

# Hyperparameter Tuning
from sklearn.model_selection import RandomizedSearchCV

# Performance Testing
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import cross_val_score

# Miscellaneous
import os, types
from botocore.client import Config
import ibm_boto3
import pickle
import joblib
from ibm_watson_machine_learning import APIClient
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 35
#      33 # Miscellaneous
#      34 import os, types
# ---> 35 from botocore.client import Config
#      36 import ibm_boto3
#      37 import pickle
#
# ModuleNotFoundError: No module named 'botocore'

# %% [markdown]
# # 1) Data Collection

# %%
# df=pd.read_csv(r"C:\Users\HP\OneDrive\College Work\Cancer Mortality & Incidence Rates Classification Using Machine Learning\Prediction Models\Prediction Model - IBM Cloud Deployment\dataset\incd.csv")


def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='hriEX2dJGKBlLf-Zia2r_c33sGYtnWhNvdUykcBrrc9f',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'cancerpredictionproject-donotdelete-pr-aslpe4kpm6ejpx'
object_key = 'incd.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df = pd.read_csv(body)
df.head()

# %%
df
# Out:
#       index                            County   FIPS  \
# 0         0              US (SEER+NPCR)(1,10)      0
# 1         1     Autauga County, Alabama(6,10)   1001
# 2         2     Baldwin County, Alabama(6,10)   1003
# 3         3     Barbour County, Alabama(6,10)   1005
# 4         4        Bibb County, Alabama(6,10)   1007
# ...     ...                               ...    ...
# 3136   3136  Sweetwater County, Wyoming(6,10)  56037
# 3137   3137       Teton County, Wyoming(6,10)  56039
# 3138   3138       Uinta County, Wyoming(6,10)  56041
# 3139   3139    Washakie County, Wyoming(6,10)  56043
# 3140   3140      Weston County, Wyoming(6,10)  56045
#
#      Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# 0                                                  62.4
# 1                                                  74.9
# 2                                                  66.9
# 3                                                  74.6
# 4                                                  86.4
# ...                                                 ...
# 3136                                               39.9
# 3137                                               23.7
# 3138                                               31.7
# 3139                                                 50
# 3140                                               44.9
#
#      Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 0                             62.3                          62.6
# 1                             65.1                          85.7
# 2                             62.4                          71.7
# 3                             61.8                          89.4
# 4                               71                         104.2
# ...                            ...                           ...
# 3136                          30.5                          51.1
# 3137                          14.7                          36.1
# 3138                          20.8                          46.1
# 3139                          33.8                          72.2
# 3140                          27.9                          69.6
#
#      Average Annual Count Recent Trend  \
# 0                  214614      falling
# 1                      43       stable
# 2                     170       stable
# 3                      25       stable
# 4                      23       stable
# ...                   ...          ...
# 3136                   14       stable
# 3137                    5       stable
# 3138                    6       stable
# 3139                    6       stable
# 3140                    4       stable
#
#      Recent 5-Year Trend (ˆ) in Incidence Rates  \
# 0                                          -2.5
# 1                                           0.5
# 2                                             3
# 3                                          -6.4
# 4                                          -4.5
# ...                                         ...
# 3136                                       12.6
# 3137                                      -19.6
# 3138                                       -0.1
# 3139                                       13.5
# 3140                                      -26.2
#
#      Lower 95% Confidence Interval.1 Upper 95% Confidence Interval.1
# 0                                 -3                              -2
# 1                              -14.9                            18.6
# 2                              -10.2                            18.3
# 3                              -18.3                             7.3
# 4                              -31.4                            32.9
# ...                              ...                             ...
# 3136                           -18.1                            54.9
# 3137                           -35.5                             0.1
# 3138                           -18.3                              22
# 3139                           -12.2                            46.7
# 3140                           -65.4                            57.4
#
# [3141 rows x 11 columns]

# %% [markdown]
# # 2) Data Preparation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Data columns (total 11 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   index                                               3141 non-null   int64
#  1   County                                              3141 non-null   object
#  2    FIPS                                               3141 non-null   int64
#  3   Age-Adjusted Incidence Rate(Ê) - cases per 100,000  3141 non-null   object
#  4   Lower 95% Confidence Interval                       3141 non-null   object
#  5   Upper 95% Confidence Interval                       3141 non-null   object
#  6   Average Annual Count                                3141 non-null   object
#  7   Recent Trend                                        3141 non-null   object
#  8   Recent 5-Year Trend (ˆ) in Incidence Rates          3141 non-null   object
#  9   Lower 95% Confidence Interval.1                     3141 non-null   object
#  10  Upper 95% Confidence Interval.1                     3141 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 270.1+ KB

# %%
# Converting object to float data type
df['Age-Adjusted Incidence Rate(Ê) - cases per 100,000'] = pd.to_numeric(df['Age-Adjusted Incidence Rate(Ê) - cases per 100,000'],errors = 'coerce')
df['Lower 95% Confidence Interval'] = pd.to_numeric(df['Lower 95% Confidence Interval'],errors = 'coerce')
df['Upper 95% Confidence Interval'] = pd.to_numeric(df['Upper 95% Confidence Interval'],errors = 'coerce')
df['Average Annual Count'] = pd.to_numeric(df['Average Annual Count'],errors = 'coerce')
df['Recent 5-Year Trend (ˆ) in Incidence Rates'] = pd.to_numeric(df['Recent 5-Year Trend (ˆ) in Incidence Rates'],errors = 'coerce')
df['Lower 95% Confidence Interval.1'] = pd.to_numeric(df['Lower 95% Confidence Interval.1'],errors = 'coerce')
df['Upper 95% Confidence Interval.1'] = pd.to_numeric(df['Upper 95% Confidence Interval.1'],errors = 'coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Data columns (total 11 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   index                                               3141 non-null   int64
#  1   County                                              3141 non-null   object
#  2    FIPS                                               3141 non-null   int64
#  3   Age-Adjusted Incidence Rate(Ê) - cases per 100,000  2640 non-null   float64
#  4   Lower 95% Confidence Interval                       2719 non-null   float64
#  5   Upper 95% Confidence Interval                       2719 non-null   float64
#  6   Average Annual Count                                2719 non-null   float64
#  7   Recent Trend                                        3141 non-null   object
#  8   Recent 5-Year Trend (ˆ) in Incidence Rates          2672 non-null   float64
#  9   Lower 95% Confidence Interval.1                     2672 non-null   float64
#  10  Upper 95% Confidence Interval.1                     2672 non-null   float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 270.1+ KB

# %% [markdown]
# ## 2.1) Dropping unwanted Features

# %%
index = df['index']
df = df.drop('index',axis=1)

# %%
df
# Out:
#                                 County   FIPS  \
# 0                 US (SEER+NPCR)(1,10)      0
# 1        Autauga County, Alabama(6,10)   1001
# 2        Baldwin County, Alabama(6,10)   1003
# 3        Barbour County, Alabama(6,10)   1005
# 4           Bibb County, Alabama(6,10)   1007
# ...                                ...    ...
# 3136  Sweetwater County, Wyoming(6,10)  56037
# 3137       Teton County, Wyoming(6,10)  56039
# 3138       Uinta County, Wyoming(6,10)  56041
# 3139    Washakie County, Wyoming(6,10)  56043
# 3140      Weston County, Wyoming(6,10)  56045
#
#       Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# 0                                                  62.4
# 1                                                  74.9
# 2                                                  66.9
# 3                                                  74.6
# 4                                                  86.4
# ...                                                 ...
# 3136                                               39.9
# 3137                                               23.7
# 3138                                               31.7
# 3139                                               50.0
# 3140                                               44.9
#
#       Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                              62.3                           62.6
# 1                              65.1                           85.7
# 2                              62.4                           71.7
# 3                              61.8                           89.4
# 4                              71.0                          104.2
# ...                             ...                            ...
# 3136                           30.5                           51.1
# 3137                           14.7                           36.1
# 3138                           20.8                           46.1
# 3139                           33.8                           72.2
# 3140                           27.9                           69.6
#
#       Average Annual Count Recent Trend  \
# 0                 214614.0      falling
# 1                     43.0       stable
# 2                    170.0       stable
# 3                     25.0       stable
# 4                     23.0       stable
# ...                    ...          ...
# 3136                  14.0       stable
# 3137                   5.0       stable
# 3138                   6.0       stable
# 3139                   6.0       stable
# 3140                   4.0       stable
#
#       Recent 5-Year Trend (ˆ) in Incidence Rates  \
# 0                                           -2.5
# 1                                            0.5
# 2                                            3.0
# 3                                           -6.4
# 4                                           -4.5
# ...                                          ...
# 3136                                        12.6
# 3137                                       -19.6
# 3138                                        -0.1
# 3139                                        13.5
# 3140                                       -26.2
#
#       Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 0                                -3.0                             -2.0
# 1                               -14.9                             18.6
# 2                               -10.2                             18.3
# 3                               -18.3                              7.3
# 4                               -31.4                             32.9
# ...                               ...                              ...
# 3136                            -18.1                             54.9
# 3137                            -35.5                              0.1
# 3138                            -18.3                             22.0
# 3139                            -12.2                             46.7
# 3140                            -65.4                             57.4
#
# [3141 rows x 10 columns]

# %% [markdown]
# ## 2.2) Handling Negative Values

# %%
print("Count of Negative Values: ")
print("Age-Adjusted Incidence Rate - cases per 100,000 ->",(df['Age-Adjusted Incidence Rate(Ê) - cases per 100,000']<0).sum())
print("Lower 95% Confidence Interval                   ->",(df['Lower 95% Confidence Interval']<0).sum())
print("Upper 95% Confidence Interval                   ->",(df['Upper 95% Confidence Interval']<0).sum())
print("Average Annual Count                            ->",(df['Average Annual Count']<0).sum())
print("Recent 5-Year Trend (ˆ) in Incidence Rates      ->",(df['Recent 5-Year Trend (ˆ) in Incidence Rates']<0).sum())
print("Lower 95% Confidence Interval.1                 ->",(df['Lower 95% Confidence Interval.1']<0).sum())
print("Upper 95% Confidence Interval.1                 ->",(df['Upper 95% Confidence Interval.1']<0).sum())
# Out:
# Count of Negative Values:
# Age-Adjusted Incidence Rate - cases per 100,000 -> 0
# Lower 95% Confidence Interval                   -> 0
# Upper 95% Confidence Interval                   -> 0
# Average Annual Count                            -> 0
# Recent 5-Year Trend (ˆ) in Incidence Rates      -> 1700
# Lower 95% Confidence Interval.1                 -> 2629
# Upper 95% Confidence Interval.1                 -> 200

# %%
df['Recent 5-Year Trend (ˆ) in Incidence Rates'] = df['Recent 5-Year Trend (ˆ) in Incidence Rates']+abs(df['Recent 5-Year Trend (ˆ) in Incidence Rates'].min())
df['Lower 95% Confidence Interval.1'] = df['Lower 95% Confidence Interval.1']+abs(df['Lower 95% Confidence Interval.1'].min())
df['Upper 95% Confidence Interval.1'] = df['Upper 95% Confidence Interval.1']+abs(df['Upper 95% Confidence Interval.1'].min())

# %%
print("Recent 5-Year Trend (ˆ) in Incidence Rates ->",(df['Recent 5-Year Trend (ˆ) in Incidence Rates']<0).sum())
print("Lower 95% Confidence Interval.1            ->",(df['Lower 95% Confidence Interval.1']<0).sum())
print("Upper 95% Confidence Interval.1            ->",(df['Upper 95% Confidence Interval.1']<0).sum())
# Out:
# Recent 5-Year Trend (ˆ) in Incidence Rates -> 0
# Lower 95% Confidence Interval.1            -> 0
# Upper 95% Confidence Interval.1            -> 0

# %%
df
# Out:
#                                 County   FIPS  \
# 0                 US (SEER+NPCR)(1,10)      0
# 1        Autauga County, Alabama(6,10)   1001
# 2        Baldwin County, Alabama(6,10)   1003
# 3        Barbour County, Alabama(6,10)   1005
# 4           Bibb County, Alabama(6,10)   1007
# ...                                ...    ...
# 3136  Sweetwater County, Wyoming(6,10)  56037
# 3137       Teton County, Wyoming(6,10)  56039
# 3138       Uinta County, Wyoming(6,10)  56041
# 3139    Washakie County, Wyoming(6,10)  56043
# 3140      Weston County, Wyoming(6,10)  56045
#
#       Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# 0                                                  62.4
# 1                                                  74.9
# 2                                                  66.9
# 3                                                  74.6
# 4                                                  86.4
# ...                                                 ...
# 3136                                               39.9
# 3137                                               23.7
# 3138                                               31.7
# 3139                                               50.0
# 3140                                               44.9
#
#       Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                              62.3                           62.6
# 1                              65.1                           85.7
# 2                              62.4                           71.7
# 3                              61.8                           89.4
# 4                              71.0                          104.2
# ...                             ...                            ...
# 3136                           30.5                           51.1
# 3137                           14.7                           36.1
# 3138                           20.8                           46.1
# 3139                           33.8                           72.2
# 3140                           27.9                           69.6
#
#       Average Annual Count Recent Trend  \
# 0                 214614.0      falling
# 1                     43.0       stable
# 2                    170.0       stable
# 3                     25.0       stable
# 4                     23.0       stable
# ...                    ...          ...
# 3136                  14.0       stable
# 3137                   5.0       stable
# 3138                   6.0       stable
# 3139                   6.0       stable
# 3140                   4.0       stable
#
#       Recent 5-Year Trend (ˆ) in Incidence Rates  \
# 0                                           37.6
# 1                                           40.6
# 2                                           43.1
# 3                                           33.7
# 4                                           35.6
# ...                                          ...
# 3136                                        52.7
# 3137                                        20.5
# 3138                                        40.0
# 3139                                        53.6
# 3140                                        13.9
#
#       Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 0                                66.0                             10.1
# 1                                54.1                             30.7
# 2                                58.8                             30.4
# 3                                50.7                             19.4
# 4                                37.6                             45.0
# ...                               ...                              ...
# 3136                             50.9                             67.0
# 3137                             33.5                             12.2
# 3138                             50.7                             34.1
# 3139                             56.8                             58.8
# 3140                              3.6                             69.5
#
# [3141 rows x 10 columns]

# %% [markdown]
# ## 2.3) Handling Missing Values

# %%
df.isnull().sum()
# Out:
# County                                                  0
#  FIPS                                                   0
# Age-Adjusted Incidence Rate(Ê) - cases per 100,000    501
# Lower 95% Confidence Interval                         422
# Upper 95% Confidence Interval                         422
# Average Annual Count                                  422
# Recent Trend                                            0
# Recent 5-Year Trend (ˆ) in Incidence Rates            469
# Lower 95% Confidence Interval.1                       469
# Upper 95% Confidence Interval.1                       469
# dtype: int64

# %% [markdown]
# ### 2.3.1) Mean Imputation for Numerical Columns

# %%
df['Age-Adjusted Incidence Rate(Ê) - cases per 100,000'].fillna(df['Age-Adjusted Incidence Rate(Ê) - cases per 100,000'].mean(),inplace=True)
df['Lower 95% Confidence Interval'].fillna(df['Lower 95% Confidence Interval'].mean(),inplace=True)
df['Upper 95% Confidence Interval'].fillna(df['Upper 95% Confidence Interval'].mean(),inplace=True)
df['Average Annual Count'].fillna(df['Average Annual Count'].mean(),inplace=True)
df['Recent 5-Year Trend (ˆ) in Incidence Rates'].fillna(df['Recent 5-Year Trend (ˆ) in Incidence Rates'].mean(),inplace=True)
df['Lower 95% Confidence Interval.1'].fillna(df['Lower 95% Confidence Interval.1'].mean(),inplace=True)
df['Upper 95% Confidence Interval.1'].fillna(df['Upper 95% Confidence Interval.1'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# County                                                0
#  FIPS                                                 0
# Age-Adjusted Incidence Rate(Ê) - cases per 100,000    0
# Lower 95% Confidence Interval                         0
# Upper 95% Confidence Interval                         0
# Average Annual Count                                  0
# Recent Trend                                          0
# Recent 5-Year Trend (ˆ) in Incidence Rates            0
# Lower 95% Confidence Interval.1                       0
# Upper 95% Confidence Interval.1                       0
# dtype: int64

# %% [markdown]
# ## 2.4) Handling Categorical Data

# %% [markdown]
# ### 2.4.1) Replacing Placeholders

# %%
df.tail(10)
# Out:
#                                 County   FIPS  \
# 3131    Niobrara County, Wyoming(6,10)  56027
# 3132        Park County, Wyoming(6,10)  56029
# 3133      Platte County, Wyoming(6,10)  56031
# 3134    Sheridan County, Wyoming(6,10)  56033
# 3135    Sublette County, Wyoming(6,10)  56035
# 3136  Sweetwater County, Wyoming(6,10)  56037
# 3137       Teton County, Wyoming(6,10)  56039
# 3138       Uinta County, Wyoming(6,10)  56041
# 3139    Washakie County, Wyoming(6,10)  56043
# 3140      Weston County, Wyoming(6,10)  56045
#
#       Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# 3131                                           69.93947
# 3132                                           36.30000
# 3133                                           52.00000
# 3134                                           52.00000
# 3135                                           69.93947
# 3136                                           39.90000
# 3137                                           23.70000
# 3138                                           31.70000
# 3139                                           50.00000
# 3140                                           44.90000
#
#       Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 3131                      57.694226                      84.786981
# 3132                      28.400000                      46.100000
# 3133                      36.400000                      73.500000
# 3134                      42.000000                      63.700000
# 3135                      57.694226                      84.786981
# 3136                      30.500000                      51.100000
# 3137                      14.700000                      36.100000
# 3138                      20.800000                      46.100000
# 3139                      33.800000                      72.200000
# 3140                      27.900000                      69.600000
#
#       Average Annual Count Recent Trend  \
# 3131            155.190879            *
# 3132             15.000000       stable
# 3133              7.000000       stable
# 3134             20.000000       stable
# 3135            155.190879            *
# 3136             14.000000       stable
# 3137              5.000000       stable
# 3138              6.000000       stable
# 3139              6.000000       stable
# 3140              4.000000       stable
#
#       Recent 5-Year Trend (ˆ) in Incidence Rates  \
# 3131                                   38.638286
# 3132                                   35.900000
# 3133                                   40.800000
# 3134                                   35.800000
# 3135                                   38.638286
# 3136                                   52.700000
# 3137                                   20.500000
# 3138                                   40.000000
# 3139                                   53.600000
# 3140                                   13.900000
#
#       Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 3131                        51.202208                        32.807036
# 3132                        57.200000                        16.000000
# 3133                        63.100000                        19.900000
# 3134                        56.500000                        16.900000
# 3135                        51.202208                        32.807036
# 3136                        50.900000                        67.000000
# 3137                        33.500000                        12.200000
# 3138                        50.700000                        34.100000
# 3139                        56.800000                        58.800000
# 3140                         3.600000                        69.500000

# %%
df['Recent Trend'].replace(['*','_','__'], ['falling','stable','rising'], inplace=True)

# %%
df.tail(10)
# Out:
#                                 County   FIPS  \
# 3131    Niobrara County, Wyoming(6,10)  56027
# 3132        Park County, Wyoming(6,10)  56029
# 3133      Platte County, Wyoming(6,10)  56031
# 3134    Sheridan County, Wyoming(6,10)  56033
# 3135    Sublette County, Wyoming(6,10)  56035
# 3136  Sweetwater County, Wyoming(6,10)  56037
# 3137       Teton County, Wyoming(6,10)  56039
# 3138       Uinta County, Wyoming(6,10)  56041
# 3139    Washakie County, Wyoming(6,10)  56043
# 3140      Weston County, Wyoming(6,10)  56045
#
#       Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# 3131                                           69.93947
# 3132                                           36.30000
# 3133                                           52.00000
# 3134                                           52.00000
# 3135                                           69.93947
# 3136                                           39.90000
# 3137                                           23.70000
# 3138                                           31.70000
# 3139                                           50.00000
# 3140                                           44.90000
#
#       Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 3131                      57.694226                      84.786981
# 3132                      28.400000                      46.100000
# 3133                      36.400000                      73.500000
# 3134                      42.000000                      63.700000
# 3135                      57.694226                      84.786981
# 3136                      30.500000                      51.100000
# 3137                      14.700000                      36.100000
# 3138                      20.800000                      46.100000
# 3139                      33.800000                      72.200000
# 3140                      27.900000                      69.600000
#
#       Average Annual Count Recent Trend  \
# 3131            155.190879      falling
# 3132             15.000000       stable
# 3133              7.000000       stable
# 3134             20.000000       stable
# 3135            155.190879      falling
# 3136             14.000000       stable
# 3137              5.000000       stable
# 3138              6.000000       stable
# 3139              6.000000       stable
# 3140              4.000000       stable
#
#       Recent 5-Year Trend (ˆ) in Incidence Rates  \
# 3131                                   38.638286
# 3132                                   35.900000
# 3133                                   40.800000
# 3134                                   35.800000
# 3135                                   38.638286
# 3136                                   52.700000
# 3137                                   20.500000
# 3138                                   40.000000
# 3139                                   53.600000
# 3140                                   13.900000
#
#       Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 3131                        51.202208                        32.807036
# 3132                        57.200000                        16.000000
# 3133                        63.100000                        19.900000
# 3134                        56.500000                        16.900000
# 3135                        51.202208                        32.807036
# 3136                        50.900000                        67.000000
# 3137                        33.500000                        12.200000
# 3138                        50.700000                        34.100000
# 3139                        56.800000                        58.800000
# 3140                         3.600000                        69.500000

# %% [markdown]
# ### 2.4.2) Ordinal Encoding

# %%
df['Recent Trend1'] = df['Recent Trend'].map({'falling':0,'stable':1,'rising':2})
df
# Out:
#                                 County   FIPS  \
# 0                 US (SEER+NPCR)(1,10)      0
# 1        Autauga County, Alabama(6,10)   1001
# 2        Baldwin County, Alabama(6,10)   1003
# 3        Barbour County, Alabama(6,10)   1005
# 4           Bibb County, Alabama(6,10)   1007
# ...                                ...    ...
# 3136  Sweetwater County, Wyoming(6,10)  56037
# 3137       Teton County, Wyoming(6,10)  56039
# 3138       Uinta County, Wyoming(6,10)  56041
# 3139    Washakie County, Wyoming(6,10)  56043
# 3140      Weston County, Wyoming(6,10)  56045
#
#       Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# 0                                                  62.4
# 1                                                  74.9
# 2                                                  66.9
# 3                                                  74.6
# 4                                                  86.4
# ...                                                 ...
# 3136                                               39.9
# 3137                                               23.7
# 3138                                               31.7
# 3139                                               50.0
# 3140                                               44.9
#
#       Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                              62.3                           62.6
# 1                              65.1                           85.7
# 2                              62.4                           71.7
# 3                              61.8                           89.4
# 4                              71.0                          104.2
# ...                             ...                            ...
# 3136                           30.5                           51.1
# 3137                           14.7                           36.1
# 3138                           20.8                           46.1
# 3139                           33.8                           72.2
# 3140                           27.9                           69.6
#
#       Average Annual Count Recent Trend  \
# 0                 214614.0      falling
# 1                     43.0       stable
# 2                    170.0       stable
# 3                     25.0       stable
# 4                     23.0       stable
# ...                    ...          ...
# 3136                  14.0       stable
# 3137                   5.0       stable
# 3138                   6.0       stable
# 3139                   6.0       stable
# 3140                   4.0       stable
#
#       Recent 5-Year Trend (ˆ) in Incidence Rates  \
# 0                                           37.6
# 1                                           40.6
# 2                                           43.1
# 3                                           33.7
# 4                                           35.6
# ...                                          ...
# 3136                                        52.7
# 3137                                        20.5
# 3138                                        40.0
# 3139                                        53.6
# 3140                                        13.9
#
#       Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1  \
# 0                                66.0                             10.1
# 1                                54.1                             30.7
# 2                                58.8                             30.4
# 3                                50.7                             19.4
# 4                                37.6                             45.0
# ...                               ...                              ...
# 3136                             50.9                             67.0
# 3137                             33.5                             12.2
# 3138                             50.7                             34.1
# 3139                             56.8                             58.8
# 3140                              3.6                             69.5
#
#       Recent Trend1
# 0                 0
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 3136              1
# 3137              1
# 3138              1
# 3139              1
# 3140              1
#
# [3141 rows x 11 columns]

# %% [markdown]
# # 3) Exploratory Data Analysis

# %% [markdown]
# ## 3.1) Univariate Analysis

# %% [markdown]
# ### 3.1.1) Histogram

# %%
df.hist(figsize=(20,20))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.1.2) Box Plot

# %%
# Removing FIPS column for better analysis
nofips = df.iloc[:,2:]
plt.figure(figsize=(15, 6))
nofips.boxplot()
plt.ylim(0,250)
plt.show()

# %% [markdown]
# ### 3.1.3) Bar Chart

# %%
plt.figure(figsize=(5, 3))
sns.countplot(x='Recent Trend', data=df)
plt.show()

# %% [markdown]
# ### 3.1.4) Kernal Density Estimation

# %%
plt.figure(figsize=(5, 2))
sns.kdeplot(data=df)
plt.show()

# %% [markdown]
# ## 3.2) Bivariate Analysis

# %% [markdown]
# ### 3.2.1) Numerical vs Numerical

# %% [markdown]
# #### 3.2.1.1) Scatter Plot

# %%
plt.figure(figsize=(8,4))
plt.subplot(121)
sns.scatterplot(x='Lower 95% Confidence Interval', y='Upper 95% Confidence Interval', hue='Recent Trend', data=df)
plt.subplot(122)
sns.scatterplot(x='Lower 95% Confidence Interval.1', y='Upper 95% Confidence Interval.1', hue='Recent Trend', data=df)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 3.2.1.2) Correlation Coefficient

# %%
corr = df['Age-Adjusted Incidence Rate(Ê) - cases per 100,000'].corr(df['Recent Trend1'])
print("Correlation coefficient between Age-Adjusted Incidence Rate - cases per 100,000 and Trend:", corr)
# Out:
# Correlation coefficient between Age-Adjusted Incidence Rate - cases per 100,000 and Trend: 0.0707987527824811

# %% [markdown]
# ### 3.2.2) Categorical vs Categorical

# %% [markdown]
# #### 3.2.2.1) Cross - Tabulation Table

# %%
ctab = pd.crosstab(df['County'], df['Recent Trend'])
ctab
# Out:
# Recent Trend                            falling  rising  stable
# County
# Abbeville County, South Carolina(6,10)        0       1       0
# Acadia Parish, Louisiana(7,9)                 0       0       1
# Accomack County, Virginia(6,10)               0       0       1
# Ada County, Idaho(6,10)                       0       0       1
# Adair County, Iowa(7,8)                       0       0       1
# ...                                         ...     ...     ...
# Yuma County, Arizona(6,10)                    0       0       1
# Yuma County, Colorado(6,10)                   0       0       1
# Zapata County, Texas(6,10)                    0       0       1
# Zavala County, Texas(6,10)                    1       0       0
# Ziebach County, South Dakota(6,10)            1       0       0
#
# [3141 rows x 3 columns]

# %% [markdown]
# #### 3.2.2.2) Chi-Square Test of Independence

# %%
cont_table = pd.crosstab(df['County'], df['Recent Trend'])
chi2, p, dof, expected = chi2_contingency(cont_table)

print('Chi-square statistic:', chi2)
print('P-value:', p)
print('Degrees of freedom:', dof)
print('Expected frequencies:\n', expected)
# Out:
# Chi-square statistic: 6282.0
# P-value: 0.4905091221376504
# Degrees of freedom: 6280
# Expected frequencies:
#  [[0.14645018 0.0191022  0.83444763]
#  [0.14645018 0.0191022  0.83444763]
#  [0.14645018 0.0191022  0.83444763]
#  ...
#  [0.14645018 0.0191022  0.83444763]
#  [0.14645018 0.0191022  0.83444763]
#  [0.14645018 0.0191022  0.83444763]]

# %% [markdown]
# #### 3.2.2.3) Stacked Bar Chart

# %%
plt.figure(figsize=(10, 5))
ctab = pd.crosstab(df['County'], df['Recent Trend'], normalize='index')
ctab.plot(kind='bar', stacked=True).xaxis.set_visible(False)
plt.title("Stacked bar chart of County vs. Recent Trend")
plt.show()

# %% [markdown]
# ### 3.2.3) Numerical vs Categorical

# %% [markdown]
# #### 3.2.3.1) Statistical Test: One-way ANOVA Test

# %%
falling = df[df["Recent Trend"] == "falling"]["Age-Adjusted Incidence Rate(Ê) - cases per 100,000"]
stable = df[df["Recent Trend"] == "stable"]["Age-Adjusted Incidence Rate(Ê) - cases per 100,000"]
rising = df[df["Recent Trend"] == "rising"]["Age-Adjusted Incidence Rate(Ê) - cases per 100,000"]
f_statistic, p_value = stats.f_oneway(falling, stable, rising)
print("f-statistic:", f_statistic)
print("p-value:", p_value)
# Out:
# f-statistic: 12.523382903523093
# p-value: 3.8260870076888755e-06

# %% [markdown]
# #### 3.2.3.2) Stacked Bar Chart

# %%
ncs = df.groupby('County')['Age-Adjusted Incidence Rate(Ê) - cases per 100,000'].sum()
ncs.plot(kind='bar',stacked=True,figsize=(10,5)).xaxis.set_visible(False)
plt.title("Stacked bar chart of Age-Adjusted Incidence Rate - cases per 100,000 by County")
plt.show()

# %% [markdown]
# ### 3.2.4) Categorical vs Numerical

# %% [markdown]
# #### 3.2.4.1) Violin Plot

# %%
plt.figure(figsize=(8,4))
# Lower 95% Confidence Interval variable, grouped by Recent Trend
plt.subplot(121)
sns.violinplot(x="Recent Trend", y="Lower 95% Confidence Interval", data=df)
# Upper 95% Confidence Interval variable, grouped by Recent Trend
plt.subplot(122)
sns.violinplot(x="Recent Trend", y="Upper 95% Confidence Interval", data=df)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,4))
# Lower 95% Confidence Interval.1 variable, grouped by Recent Trend
plt.subplot(121)
sns.violinplot(x="Recent Trend", y="Lower 95% Confidence Interval.1", data=df)
# Upper 95% Confidence Interval.1 variable, grouped by Recent Trend
plt.subplot(122)
sns.violinplot(x="Recent Trend", y="Upper 95% Confidence Interval.1", data=df)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 3.2.4.2) Strip Plot

# %%
plt.figure(figsize=(8,4))
# Lower 95% Confidence Interval variable, grouped by Recent Trend
plt.subplot(121)
sns.stripplot(x="Recent Trend", y="Lower 95% Confidence Interval", data=df)
# Upper 95% Confidence Interval variable, grouped by Recent Trend
plt.subplot(122)
sns.stripplot(x="Recent Trend", y="Upper 95% Confidence Interval", data=df)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,4))
# Lower 95% Confidence Interval.1 variable, grouped by Recent Trend
plt.subplot(121)
sns.stripplot(x="Recent Trend", y="Lower 95% Confidence Interval.1", data=df)
# Upper 95% Confidence Interval.1 variable, grouped by Recent Trend
plt.subplot(122)
sns.stripplot(x="Recent Trend", y="Upper 95% Confidence Interval.1", data=df)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3.3) Multivariate Analysis

# %% [markdown]
# ### 3.3.1) Heatmap - Correlation Matrix

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df.corr(), annot=True, cmap="Blues")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### 3.3.2) Scatter Plot

# %%
plt.figure(figsize=(10,4))
# Lower 95% Confidence Interval vs. Upper 95% Confidence Interval with color coded by Recent Trend
plt.subplot(121)
plt.scatter(df['Lower 95% Confidence Interval'], df['Upper 95% Confidence Interval'], c=df['Recent Trend'].map({'falling': 0, 'stable': 1, 'rising': 2}))
plt.xlabel('Lower 95% Confidence Interval')
plt.ylabel('Upper 95% Confidence Interval')
plt.colorbar(ticks=[0, 1, 2], label='Recent Trend')
# Lower 95% Confidence Interval.1 vs. Upper 95% Confidence Interval.1 with color coded by Recent Trend
plt.subplot(122)
plt.scatter(df['Lower 95% Confidence Interval.1'], df['Upper 95% Confidence Interval.1'], c=df['Recent Trend'].map({'falling': 0, 'stable': 1, 'rising': 2}))
plt.xlabel('Lower 95% Confidence Interval.1')
plt.ylabel('Upper 95% Confidence Interval.1')
plt.colorbar(ticks=[0, 1, 2], label='Recent Trend')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.3.3) Scatter Plot Matrix

# %%
# Selecting numerical columns
num_vars = ['Lower 95% Confidence Interval','Upper 95% Confidence Interval','Age-Adjusted Incidence Rate(Ê) - cases per 100,000', 'Average Annual Count', 'Recent 5-Year Trend (ˆ) in Incidence Rates','Lower 95% Confidence Interval.1','Upper 95% Confidence Interval.1']

plt.figure(figsize=(16,5))
sns.pairplot(df[num_vars])
plt.show()

# %% [markdown]
# ### 3.3.4) Factor Analysis

# %%
X = df[num_vars]
fa = FactorAnalyzer(n_factors=2, rotation='varimax')
fa.fit(X)
print(fa.loadings_)
# Out:
# [[ 0.91054618 -0.18402275]
#  [ 0.8584551   0.2888072 ]
#  [ 1.01177564  0.05222917]
#  [-0.00871315 -0.03901443]
#  [ 0.04596465  0.29224439]
#  [ 0.05629651 -0.40520562]
#  [-0.05192348  1.03854902]]

# %% [markdown]
# ## 3.4) Descriptive Analysis

# %% [markdown]
# ### 3.4.1) Stats for Numerical Columns

# %%
df.describe()
# Out:
#                FIPS  Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# count   3141.000000                                        3141.000000
# mean   30392.281757                                          69.939470
# std    15158.200839                                          16.475314
# min        0.000000                                          13.500000
# 25%    18179.000000                                          60.800000
# 50%    29177.000000                                          69.939470
# 75%    45081.000000                                          77.900000
# max    56045.000000                                         203.700000
#
#        Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# count                    3141.000000                    3141.000000
# mean                       57.694226                      84.786981
# std                        15.263744                      20.909910
# min                         7.600000                      18.300000
# 25%                        48.600000                      72.600000
# 50%                        57.694226                      84.786981
# 75%                        66.500000                      93.800000
# max                       172.400000                     239.100000
#
#        Average Annual Count  Recent 5-Year Trend (ˆ) in Incidence Rates  \
# count           3141.000000                                 3141.000000
# mean             155.190879                                   38.638286
# std             3831.472832                                    7.251884
# min                3.000000                                    0.000000
# 25%               15.000000                                   35.400000
# 50%               35.000000                                   38.638286
# 75%              121.000000                                   41.100000
# max           214614.000000                                   84.300000
#
#        Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1  \
# count                      3141.000000                      3141.000000
# mean                         51.202208                        32.807036
# std                          11.211491                        21.779930
# min                           0.000000                         0.000000
# 25%                          45.800000                        18.400000
# 50%                          51.202208                        30.300000
# 75%                          58.700000                        37.600000
# max                          88.400000                       208.000000
#
#        Recent Trend1
# count    3141.000000
# mean        0.872652
# std         0.386500
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         2.000000

# %% [markdown]
# ### 3.4.2) Stats for Categorical columns

# %%
print(df['County'].value_counts(),'\n')
print(df['Recent Trend'].value_counts(),'\n')
# Out:
# US (SEER+NPCR)(1,10)             1
# Logan County, Ohio(6,10)         1
# Lucas County, Ohio(6,10)         1
# Madison County, Ohio(6,10)       1
# Mahoning County, Ohio(6,10)      1
#                                 ..
# Johnson County, Kentucky(7,9)    1
# Kenton County, Kentucky(7,9)     1
# Knott County, Kentucky(7,9)      1
# Knox County, Kentucky(7,9)       1
# Weston County, Wyoming(6,10)     1
# Name: County, Length: 3141, dtype: int64
#
# stable     2621
# falling     460
# rising       60
# Name: Recent Trend, dtype: int64

# %% [markdown]
# ### 3.4.3) Overall Stats

# %%
# Calculating variance, standard deviation, skewness, and kurtosis for each numerical variable
mean_values = df.mean(numeric_only=True)
median_values = df.median(numeric_only=True)
variance_values = df.var(numeric_only=True)
std_values = df.std(numeric_only=True)
skewness_values = df.skew(numeric_only=True)
kurtosis_values = df.kurtosis(numeric_only=True)

fig, axs = plt.subplots(3, 2, figsize=(10,10))

# Mean
axs[0, 0].bar(mean_values.index, mean_values.values)
axs[0, 0].set_ylabel('Mean')
axs[0, 0].set_title('Mean Values')
axs[0, 0].xaxis.set_visible(False)

# Median
axs[0, 1].bar(median_values.index, median_values.values)
axs[0, 1].set_ylabel('Median')
axs[0, 1].set_title('Median Values')
axs[0, 1].xaxis.set_visible(False)

# Variance
axs[1, 0].bar(variance_values.index, variance_values.values)
axs[1, 0].set_ylabel('Variance')
axs[1, 0].set_title('Variance Values')
axs[1, 0].xaxis.set_visible(False)

# Standard deviation
axs[1, 1].bar(std_values.index, std_values.values)
axs[1, 1].set_ylabel('Standard Deviation')
axs[1, 1].set_title('Standard Deviation Values')
axs[1, 1].xaxis.set_visible(False)

# Skewness 
axs[2, 0].bar(skewness_values.index, skewness_values.values)
axs[2, 0].set_ylabel('Skewness')
axs[2, 0].set_title('Skewness Values')
axs[2, 0].xaxis.set_visible(False)

# Kurtosis
axs[2, 1].bar(kurtosis_values.index, kurtosis_values.values)
axs[2, 1].set_ylabel('Kurtosis')
axs[2, 1].set_title('Kurtosis Values')
axs[2, 1].xaxis.set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.4.4) Measures of Central Tendency

# %% [markdown]
# #### 3.4.4.1) Mean

# %%
plt.figure(figsize=(5,3))
a = df.groupby('County')['Age-Adjusted Incidence Rate(Ê) - cases per 100,000'].mean()
a.plot().xaxis.set_visible(False)

# %% [markdown]
# #### 3.4.4.2) Median

# %%
plt.figure(figsize=(5,3))
b = df.groupby('County')['Age-Adjusted Incidence Rate(Ê) - cases per 100,000'].median()
b.plot().xaxis.set_visible(False)

# %% [markdown]
# #### 3.4.4.3) Mode

# %%
df.mode()
# Out:
#                                       County   FIPS  \
# 0     Abbeville County, South Carolina(6,10)      0
# 1              Acadia Parish, Louisiana(7,9)   1001
# 2            Accomack County, Virginia(6,10)   1003
# 3                    Ada County, Idaho(6,10)   1005
# 4                    Adair County, Iowa(7,8)   1007
# ...                                      ...    ...
# 3136              Yuma County, Arizona(6,10)  56037
# 3137             Yuma County, Colorado(6,10)  56039
# 3138              Zapata County, Texas(6,10)  56041
# 3139              Zavala County, Texas(6,10)  56043
# 3140      Ziebach County, South Dakota(6,10)  56045
#
#       Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# 0                                              69.93947
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3136                                                NaN
# 3137                                                NaN
# 3138                                                NaN
# 3139                                                NaN
# 3140                                                NaN
#
#       Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                         57.694226                      84.786981
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
# ...                             ...                            ...
# 3136                            NaN                            NaN
# 3137                            NaN                            NaN
# 3138                            NaN                            NaN
# 3139                            NaN                            NaN
# 3140                            NaN                            NaN
#
#       Average Annual Count Recent Trend  \
# 0               155.190879       stable
# 1                      NaN          NaN
# 2                      NaN          NaN
# 3                      NaN          NaN
# 4                      NaN          NaN
# ...                    ...          ...
# 3136                   NaN          NaN
# 3137                   NaN          NaN
# 3138                   NaN          NaN
# 3139                   NaN          NaN
# 3140                   NaN          NaN
#
#       Recent 5-Year Trend (ˆ) in Incidence Rates  \
# 0                                      38.638286
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 3136                                         NaN
# 3137                                         NaN
# 3138                                         NaN
# 3139                                         NaN
# 3140                                         NaN
#
#       Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1  \
# 0                           51.202208                        32.807036
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                                 NaN                              NaN
# ...                               ...                              ...
# 3136                              NaN                              NaN
# 3137                              NaN                              NaN
# 3138                              NaN                              NaN
# 3139                              NaN                              NaN
# 3140                              NaN                              NaN
#
#       Recent Trend1
# 0               1.0
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3136            NaN
# 3137            NaN
# 3138            NaN
# 3139            NaN
# 3140            NaN
#
# [3141 rows x 11 columns]

# %% [markdown]
# ### 3.4.5) Measures of Dispersion

# %% [markdown]
# #### 3.4.5.1) Variance

# %%
df.var(numeric_only=True)
# Out:
#  FIPS                                                 2.297711e+08
# Age-Adjusted Incidence Rate(Ê) - cases per 100,000    2.714360e+02
# Lower 95% Confidence Interval                         2.329819e+02
# Upper 95% Confidence Interval                         4.372244e+02
# Average Annual Count                                  1.468018e+07
# Recent 5-Year Trend (ˆ) in Incidence Rates            5.258982e+01
# Lower 95% Confidence Interval.1                       1.256975e+02
# Upper 95% Confidence Interval.1                       4.743654e+02
# Recent Trend1                                         1.493824e-01
# dtype: float64

# %% [markdown]
# #### 3.4.5.2) Range

# %%
num_col = df.select_dtypes(include='number')
r = num_col.max() - num_col.min()
r
# Out:
#  FIPS                                                  56045.0
# Age-Adjusted Incidence Rate(Ê) - cases per 100,000       190.2
# Lower 95% Confidence Interval                            164.8
# Upper 95% Confidence Interval                            220.8
# Average Annual Count                                  214611.0
# Recent 5-Year Trend (ˆ) in Incidence Rates                84.3
# Lower 95% Confidence Interval.1                           88.4
# Upper 95% Confidence Interval.1                          208.0
# Recent Trend1                                              2.0
# dtype: float64

# %% [markdown]
# ### 3.4.6) Measures of Shape and Skewness

# %% [markdown]
# #### 3.4.6.1) Skew

# %%
df.skew(numeric_only=True)
# Out:
#  FIPS                                                 -0.079776
# Age-Adjusted Incidence Rate(Ê) - cases per 100,000     0.659159
# Lower 95% Confidence Interval                          0.279102
# Upper 95% Confidence Interval                          0.963586
# Average Annual Count                                  55.883856
# Recent 5-Year Trend (ˆ) in Incidence Rates             0.627448
# Lower 95% Confidence Interval.1                       -0.829423
# Upper 95% Confidence Interval.1                        2.623315
# Recent Trend1                                         -1.182885
# dtype: float64

# %% [markdown]
# #### 3.4.6.2) Kurtosis

# %%
df.kurtosis(numeric_only=True)
# Out:
#  FIPS                                                   -1.097491
# Age-Adjusted Incidence Rate(Ê) - cases per 100,000       3.501202
# Lower 95% Confidence Interval                            2.035791
# Upper 95% Confidence Interval                            3.776066
# Average Annual Count                                  3128.932827
# Recent 5-Year Trend (ˆ) in Incidence Rates               5.130439
# Lower 95% Confidence Interval.1                          1.245339
# Upper 95% Confidence Interval.1                         11.057830
# Recent Trend1                                            2.207112
# dtype: float64

# %% [markdown]
# ### 3.4.7) Percentile

# %%
df.quantile([0.25,0.5,0.75], numeric_only=True)
# Out:
#          FIPS  Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# 0.25  18179.0                                           60.80000
# 0.50  29177.0                                           69.93947
# 0.75  45081.0                                           77.90000
#
#       Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0.25                      48.600000                      72.600000
# 0.50                      57.694226                      84.786981
# 0.75                      66.500000                      93.800000
#
#       Average Annual Count  Recent 5-Year Trend (ˆ) in Incidence Rates  \
# 0.25                  15.0                                   35.400000
# 0.50                  35.0                                   38.638286
# 0.75                 121.0                                   41.100000
#
#       Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1  \
# 0.25                        45.800000                             18.4
# 0.50                        51.202208                             30.3
# 0.75                        58.700000                             37.6
#
#       Recent Trend1
# 0.25            1.0
# 0.50            1.0
# 0.75            1.0

# %% [markdown]
# # 4) Data Pre-processing

# %% [markdown]
# ## 4.1) Handling Outliers

# %%
# Remove FIPS for better Analysis
nofips = df.iloc[:,2:]
plt.figure(figsize=(15, 6))
nofips.boxplot()
plt.ylim(0,250)
plt.show()

# %%
for i in num_vars:
    df[i]= winsorize(df[i],limits=[0.1,0.1])

# %%
nofips = df.iloc[:,2:]
plt.figure(figsize=(15, 6))
nofips.boxplot()
plt.ylim(0,250)
plt.show()

# %% [markdown]
# ## 4.2) Splitting Dataset

# %% [markdown]
# ### 4.2.1) Independent Variables

# %%
X = df.drop(['Recent Trend1','County','Recent Trend'], axis=1)
X
# Out:
#        FIPS  Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# 0         0                                               62.4
# 1      1001                                               74.9
# 2      1003                                               66.9
# 3      1005                                               74.6
# 4      1007                                               86.4
# ...     ...                                                ...
# 3136  56037                                               49.4
# 3137  56039                                               49.4
# 3138  56041                                               49.4
# 3139  56043                                               50.0
# 3140  56045                                               49.4
#
#       Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                              62.3                           62.6
# 1                              65.1                           85.7
# 2                              62.4                           71.7
# 3                              61.8                           89.4
# 4                              71.0                          104.2
# ...                             ...                            ...
# 3136                           38.0                           60.5
# 3137                           38.0                           60.5
# 3138                           38.0                           60.5
# 3139                           38.0                           72.2
# 3140                           38.0                           69.6
#
#       Average Annual Count  Recent 5-Year Trend (ˆ) in Incidence Rates  \
# 0               155.190879                                        37.6
# 1                43.000000                                        40.6
# 2               155.190879                                        43.1
# 3                25.000000                                        33.7
# 4                23.000000                                        35.6
# ...                    ...                                         ...
# 3136             14.000000                                        46.4
# 3137              7.000000                                        30.9
# 3138              7.000000                                        40.0
# 3139              7.000000                                        46.4
# 3140              7.000000                                        30.9
#
#       Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 0                                64.8                             13.1
# 1                                54.1                             30.7
# 2                                58.8                             30.4
# 3                                50.7                             19.4
# 4                                37.6                             45.0
# ...                               ...                              ...
# 3136                             50.9                             56.3
# 3137                             35.8                             13.1
# 3138                             50.7                             34.1
# 3139                             56.8                             56.3
# 3140                             35.8                             56.3
#
# [3141 rows x 8 columns]

# %% [markdown]
# ### 4.2.2) Dependent variable

# %%
y = df['Recent Trend1']
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3136    1
# 3137    1
# 3138    1
# 3139    1
# 3140    1
# Name: Recent Trend1, Length: 3141, dtype: int64

# %% [markdown]
# ## 4.3) Handling Imbalanced Data

# %% [markdown]
# ### 4.3.1)  SMOTE (Synthetic Minority Over-sampling Technique)

# %%
sm=SMOTE(random_state=2) 
X_res, y_res = sm.fit_resample (X, y)

# %%
X_res
# Out:
#        FIPS  Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# 0         0                                          62.400000
# 1      1001                                          74.900000
# 2      1003                                          66.900000
# 3      1005                                          74.600000
# 4      1007                                          86.400000
# ...     ...                                                ...
# 7858  32027                                          69.939470
# 7859  53055                                          79.943380
# 7860  47385                                          58.395448
# 7861  29095                                          55.727802
# 7862  50574                                          55.922501
#
#       Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                         62.300000                      62.600000
# 1                         65.100000                      85.700000
# 2                         62.400000                      71.700000
# 3                         61.800000                      89.400000
# 4                         71.000000                     104.200000
# ...                             ...                            ...
# 7858                      57.694226                      84.786981
# 7859                      67.742814                      97.460506
# 7860                      47.392431                      71.573342
# 7861                      39.276057                      77.331290
# 7862                      39.880825                      82.318358
#
#       Average Annual Count  Recent 5-Year Trend (ˆ) in Incidence Rates  \
# 0               155.190879                                   37.600000
# 1                43.000000                                   40.600000
# 2               155.190879                                   43.100000
# 3                25.000000                                   33.700000
# 4                23.000000                                   35.600000
# ...                    ...                                         ...
# 7858            155.190879                                   38.638286
# 7859             33.771407                                   46.400000
# 7860             20.376853                                   46.287438
# 7861              7.741278                                   46.400000
# 7862             10.083320                                   46.400000
#
#       Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 0                           64.800000                        13.100000
# 1                           54.100000                        30.700000
# 2                           58.800000                        30.400000
# 3                           50.700000                        19.400000
# 4                           37.600000                        45.000000
# ...                               ...                              ...
# 7858                        51.202208                        32.807036
# 7859                        64.800000                        29.708563
# 7860                        64.800000                        35.500547
# 7861                        64.800000                        33.123588
# 7862                        64.800000                        47.600847
#
# [7863 rows x 8 columns]

# %%
y_res
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7858    2
# 7859    2
# 7860    2
# 7861    2
# 7862    2
# Name: Recent Trend1, Length: 7863, dtype: int64

# %% [markdown]
# ## 4.4) Splitting into Train and Test

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=0)

# %%
X_train
# Out:
#        FIPS  Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# 7156  19043                                          69.708795
# 3490  30022                                          69.939470
# 4832  17059                                          87.943329
# 6730  44601                                          68.266029
# 6777  36368                                          69.670249
# ...     ...                                                ...
# 4931  31087                                          69.939470
# 3264  26016                                          70.456078
# 1653  31001                                          62.700000
# 2607  48171                                          49.400000
# 2732  48421                                          69.939470
#
#       Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 7156                      50.418779                      94.485895
# 3490                      57.694226                      84.786981
# 4832                      62.384548                     110.275428
# 6730                      55.259171                      84.158372
# 6777                      62.311789                      77.801872
# ...                             ...                            ...
# 4931                      57.694226                      84.786981
# 3264                      66.748150                      88.692084
# 1653                      51.700000                      75.400000
# 2607                      40.400000                      60.500000
# 2732                      57.694226                      84.786981
#
#       Average Annual Count  Recent 5-Year Trend (ˆ) in Incidence Rates  \
# 7156              9.000000                                   43.187084
# 3490            155.190879                                   38.638286
# 4832              9.029072                                   30.900000
# 6730             21.786285                                   45.279864
# 6777             67.878641                                   43.213419
# ...                    ...                                         ...
# 4931            155.190879                                   38.638286
# 3264             46.803291                                   32.161561
# 1653             24.000000                                   46.400000
# 2607             25.000000                                   30.900000
# 2732            155.190879                                   38.638286
#
#       Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 7156                        64.800000                        17.387084
# 3490                        51.202208                        32.807036
# 4832                        48.694783                        13.100000
# 6730                        64.800000                        25.483451
# 6777                        64.800000                        17.626838
# ...                               ...                              ...
# 4931                        51.202208                        32.807036
# 3264                        56.799048                        13.100000
# 1653                        56.700000                        42.800000
# 2607                        37.900000                        22.700000
# 2732                        51.202208                        32.807036
#
# [6290 rows x 8 columns]

# %%
X_test
# Out:
#        FIPS  Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# 1817  35043                                          49.400000
# 6459  19117                                          62.773932
# 7330  29023                                          77.747879
# 6135  29071                                          78.943883
# 7186  52998                                          74.354115
# ...     ...                                                ...
# 5786  12682                                          74.160227
# 2359  45089                                          66.300000
# 3464   6064                                          49.400000
# 1173  22123                                          78.500000
# 2894  51161                                          55.200000
#
#       Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 1817                      38.000000                      60.500000
# 6459                      45.882621                      84.833726
# 7330                      65.767685                      91.584678
# 6135                      62.562394                      99.095585
# 7186                      60.129175                      93.924514
# ...                             ...                            ...
# 5786                      61.587049                      87.421344
# 2359                      55.800000                      78.400000
# 3464                      44.781709                      60.500000
# 1173                      59.500000                     102.000000
# 2894                      49.600000                      61.400000
#
#       Average Annual Count  Recent 5-Year Trend (ˆ) in Incidence Rates  \
# 1817             58.000000                                   38.900000
# 6459              9.385862                                   42.945655
# 7330             35.103759                                   43.473115
# 6135             21.708511                                   45.099681
# 7186             23.547819                                   46.400000
# ...                    ...                                         ...
# 5786             32.671475                                   46.091269
# 2359             29.000000                                   46.000000
# 3464            155.190879                                   34.627204
# 1173             12.000000                                   34.700000
# 2894             72.000000                                   30.900000
#
#       Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 1817                        64.800000                        13.100000
# 6459                        64.800000                        17.107069
# 7330                        64.800000                        20.180435
# 6135                        64.800000                        30.083351
# 7186                        64.800000                        45.794372
# ...                               ...                              ...
# 5786                        64.800000                        28.029339
# 2359                        64.800000                        23.500000
# 3464                        60.481709                        13.100000
# 1173                        44.300000                        30.900000
# 2894                        49.900000                        13.100000
#
# [1573 rows x 8 columns]

# %%
y_train
# Out:
# 7156    2
# 3490    0
# 4832    0
# 6730    2
# 6777    2
#        ..
# 4931    0
# 3264    0
# 1653    1
# 2607    1
# 2732    0
# Name: Recent Trend1, Length: 6290, dtype: int64

# %%
y_test
# Out:
# 1817    1
# 6459    2
# 7330    2
# 6135    2
# 7186    2
#        ..
# 5786    2
# 2359    2
# 3464    0
# 1173    1
# 2894    1
# Name: Recent Trend1, Length: 1573, dtype: int64

# %% [markdown]
# # 5) Model Building

# %% [markdown]
# ## 5.1) Training the model in multiple algorithms and Performance Testing

# %% [markdown]
# ### 5.1.1) Random Forest Classifier

# %%
rfc= RandomForestClassifier(random_state=42)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rfc.predict(X_test)
y_pred
# Out:
# array([1, 2, 2, ..., 0, 1, 0])

# %%
print("Classification Report\n",classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix\n",cm)

print("\nTrain score:", rfc.score (X_train, y_train), "\nTest score:",rfc.score (X_test, y_test))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       518
#            1       0.97      0.96      0.97       521
#            2       0.99      0.99      0.99       534
#
#     accuracy                           0.98      1573
#    macro avg       0.98      0.98      0.98      1573
# weighted avg       0.98      0.98      0.98      1573
#
# Confusion Matrix
#  [[506  12   0]
#  [ 13 502   6]
#  [  0   3 531]]
#
# Train score: 1.0
# Test score: 0.9783852511125238

# %% [markdown]
# ### 5.1.2) Decision Tree Classifer

# %%
dtc = DecisionTreeClassifier(random_state=42)
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = dtc.predict(X_test)
y_pred
# Out:
# array([0, 2, 2, ..., 0, 1, 0])

# %%
print("Classification Report\n",classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix\n",cm)

print("\nTrain score:", dtc.score (X_train, y_train), "\nTest score:",dtc.score (X_test, y_test))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95       518
#            1       0.93      0.93      0.93       521
#            2       0.98      0.99      0.98       534
#
#     accuracy                           0.95      1573
#    macro avg       0.95      0.95      0.95      1573
# weighted avg       0.95      0.95      0.95      1573
#
# Confusion Matrix
#  [[491  27   0]
#  [ 29 483   9]
#  [  0   8 526]]
#
# Train score: 1.0
# Test score: 0.9535918626827717

# %% [markdown]
# ### 5.1.3) Gradient Boosting Classifier

# %%
gbc = GradientBoostingClassifier(random_state=42)
gbc.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_pred = gbc.predict(X_test)
y_pred
# Out:
# array([0, 2, 2, ..., 0, 1, 0])

# %%
print("Classification Report\n",classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix\n",cm)

print("\nTrain score:", gbc.score (X_train, y_train), "\nTest score:",gbc.score (X_test, y_test))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96       518
#            1       0.95      0.95      0.95       521
#            2       0.98      1.00      0.99       534
#
#     accuracy                           0.97      1573
#    macro avg       0.97      0.97      0.97      1573
# weighted avg       0.97      0.97      0.97      1573
#
# Confusion Matrix
#  [[494  24   0]
#  [ 18 494   9]
#  [  0   1 533]]
#
# Train score: 0.9772655007949126
# Test score: 0.9669421487603306

# %% [markdown]
# ### 5.1.4) Ada Boost Classifier

# %%
abc = AdaBoostClassifier(random_state=42)
abc.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(random_state=42)

# %%
y_pred = abc.predict(X_test)
y_pred
# Out:
# array([0, 1, 1, ..., 0, 1, 0])

# %%
print("Classification Report\n",classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix\n",cm)

print("\nTrain score:", abc.score (X_train, y_train), "\nTest score:",abc.score (X_test, y_test))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.80      0.85      0.83       518
#            1       0.47      0.79      0.59       521
#            2       1.00      0.29      0.45       534
#
#     accuracy                           0.64      1573
#    macro avg       0.76      0.64      0.62      1573
# weighted avg       0.76      0.64      0.62      1573
#
# Confusion Matrix
#  [[442  76   0]
#  [111 410   0]
#  [  0 379 155]]
#
# Train score: 0.6518282988871225
# Test score: 0.6401780038143674

# %% [markdown]
# ### 5.1.5) K Nearest Neighbors Classifier

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)
y_pred
# Out:
# array([1, 2, 2, ..., 0, 1, 0])

# %%
print("Classification Report\n",classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix\n",cm)

print("\nTrain score:", knn.score (X_train, y_train), "\nTest score:",knn.score (X_test, y_test))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       518
#            1       0.85      0.75      0.80       521
#            2       0.91      0.92      0.91       534
#
#     accuracy                           0.86      1573
#    macro avg       0.86      0.86      0.85      1573
# weighted avg       0.86      0.86      0.85      1573
#
# Confusion Matrix
#  [[463  45  10]
#  [ 90 392  39]
#  [ 17  26 491]]
#
# Train score: 0.9054054054054054
# Test score: 0.8556897647806738

# %% [markdown]
# ### 5.1.6) Logistic Regression

# %%
lr = LogisticRegression(random_state=42)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([2, 2, 2, ..., 0, 1, 0])

# %%
print("Classification Report\n",classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix\n",cm)

print("\nTrain score:", lr.score (X_train, y_train), "\nTest score:",lr.score (X_test, y_test))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.59      0.73      0.65       518
#            1       0.75      0.54      0.63       521
#            2       0.63      0.66      0.65       534
#
#     accuracy                           0.64      1573
#    macro avg       0.66      0.64      0.64      1573
# weighted avg       0.66      0.64      0.64      1573
#
# Confusion Matrix
#  [[378  66  74]
#  [111 279 131]
#  [153  26 355]]
#
# Train score: 0.6343402225755167
# Test score: 0.6433566433566433

# %% [markdown]
# ### 5.1.7) Support Vector Machines

# %%
svm = SVC(random_state=42)
svm.fit(X_train, y_train)
# Out:
# SVC(random_state=42)

# %%
y_pred = svm.predict(X_test)
y_pred
# Out:
# array([2, 1, 2, ..., 0, 2, 0])

# %%
print("Classification Report\n",classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix\n",cm)

print("\nTrain score:", svm.score (X_train, y_train), "\nTest score:",svm.score (X_test, y_test))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.47      0.56      0.51       518
#            1       0.36      0.23      0.28       521
#            2       0.49      0.56      0.52       534
#
#     accuracy                           0.45      1573
#    macro avg       0.44      0.45      0.44      1573
# weighted avg       0.44      0.45      0.44      1573
#
# Confusion Matrix
#  [[291  86 141]
#  [226 122 173]
#  [101 133 300]]
#
# Train score: 0.45961844197138313
# Test score: 0.4532739987285442

# %% [markdown]
# ### 5.1.8) Gaussian Naive Bayes Classifier

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)
y_pred
# Out:
# array([1, 2, 2, ..., 0, 1, 0])

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
print("Classification Report\n",classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix\n",cm)

print("\nTrain score:", gnb.score (X_train, y_train), "\nTest score:",gnb.score (X_test, y_test))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67       518
#            1       0.67      0.54      0.60       521
#            2       0.82      0.66      0.73       534
#
#     accuracy                           0.67      1573
#    macro avg       0.69      0.67      0.67      1573
# weighted avg       0.69      0.67      0.67      1573
#
# Confusion Matrix
#  [[414 104   0]
#  [160 283  78]
#  [146  33 355]]
#
# Train score: 0.6686804451510334
# Test score: 0.6687857596948507

# %% [markdown]
# ### 5.1.9) XGBoost Classifier

# %%
xb = xgb.XGBClassifier()
xb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...)

# %%
y_pred = xb.predict(X_test)
y_pred
# Out:
# array([0, 2, 2, ..., 0, 1, 0])

# %%
print("Classification Report\n",classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix\n",cm)

print("\nTrain score:", xb.score (X_train, y_train), "\nTest score:",xb.score (X_test, y_test))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       518
#            1       0.98      0.97      0.97       521
#            2       0.99      1.00      0.99       534
#
#     accuracy                           0.98      1573
#    macro avg       0.98      0.98      0.98      1573
# weighted avg       0.98      0.98      0.98      1573
#
# Confusion Matrix
#  [[509   9   0]
#  [ 11 504   6]
#  [  0   0 534]]
#
# Train score: 1.0
# Test score: 0.9834710743801653

# %% [markdown]
# ## 5.2) Hyperparameter Tuning

# %% [markdown]
# ### 5.2.1) Cross Validation Score before Hyper Parameter Tuning

# %%
rfc_s = cross_val_score(rfc, X, y, cv=5, scoring='accuracy')
dtc_s = cross_val_score(dtc, X, y, cv=5, scoring='accuracy')
gbc_s = cross_val_score(gbc, X, y, cv=5, scoring='accuracy')
abc_s = cross_val_score(abc, X, y, cv=5, scoring='accuracy')
knn_s = cross_val_score(knn, X, y, cv=5, scoring='accuracy')
lr_s =  cross_val_score( lr, X, y, cv=5, scoring='accuracy')
svm_s = cross_val_score(svm, X, y, cv=5, scoring='accuracy')
gnb_s = cross_val_score(gnb, X, y, cv=5, scoring='accuracy')
xb_s = cross_val_score(xb, X, y, cv=5, scoring='accuracy')
# Print the average accuracy and standard deviation of the scores
print("Accuracy of Random Forest Classifier       : %0.2f (+/- %0.2f)" % (rfc_s.mean(), rfc_s.std() * 2))
print("Accuracy of Decision Tree Classifier       : %0.2f (+/- %0.2f)" % (dtc_s.mean(), dtc_s.std() * 2))
print("Accuracy of Gradient Boosting Classifier   : %0.2f (+/- %0.2f)" % (gbc_s.mean(), gbc_s.std() * 2))
print("Accuracy of Ada Boost Classifier           : %0.2f (+/- %0.2f)" % (abc_s.mean(), abc_s.std() * 2))
print("Accuracy of K Nearest Neighbours           : %0.2f (+/- %0.2f)" % (knn_s.mean(), knn_s.std() * 2))
print("Accuracy of Logistic Regression            : %0.2f (+/- %0.2f)" % ( lr_s.mean(),  lr_s.std() * 2))
print("Accuracy of Support Vector Machines        : %0.2f (+/- %0.2f)" % (svm_s.mean(), svm_s.std() * 2))
print("Accuracy of Gaussian Naive Bayes Classifier: %0.2f (+/- %0.2f)" % (gnb_s.mean(), gnb_s.std() * 2))
print("Accuracy of XGBoost Classifier             : %0.2f (+/- %0.2f)" % (xb_s.mean(), xb_s.std() * 2))
# Out:
# Accuracy of Random Forest Classifier       : 0.92 (+/- 0.11)
# Accuracy of Decision Tree Classifier       : 0.63 (+/- 0.66)
# Accuracy of Gradient Boosting Classifier   : 0.78 (+/- 0.46)
# Accuracy of Ada Boost Classifier           : 0.72 (+/- 0.30)
# Accuracy of K Nearest Neighbours           : 0.19 (+/- 0.04)
# Accuracy of Logistic Regression            : 0.85 (+/- 0.06)
# Accuracy of Support Vector Machines        : 0.83 (+/- 0.00)
# Accuracy of Gaussian Naive Bayes Classifier: 0.77 (+/- 0.09)
# Accuracy of XGBoost Classifier             : 0.90 (+/- 0.13)

# %% [markdown]
# ### 5.2.2) Performing Hyperparameter Tuning for Two Best Models

# %% [markdown]
# #### 5.2.2.1) Random Forest Classifier

# %%
params = {
    'n_estimators': [100, 200, 500],
    'max_depth': [3, 5, 10, None],
    'max_features': ['sqrt', 'log2'],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}
rfc_cv = RandomizedSearchCV(rfc, param_distributions=params, cv=5, n_iter=10, scoring='accuracy', random_state=42)
rfc_cv.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    param_distributions={'max_depth': [3, 5, 10, None],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 500]},
#                    random_state=42, scoring='accuracy')

# %%
rfc_best_model = rfc_cv.best_estimator_
rfc_best_model
# Out:
# RandomForestClassifier(max_features='log2', min_samples_leaf=2,
#                        min_samples_split=5, random_state=42)

# %%
predictions = rfc_best_model.predict(X)
predictions
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
print("Classification Report:\n")
print(classification_report(y, predictions))
print("\nBest Hyperparameters: ", rfc_cv.best_params_)
print("\nAccuracy Score: %.2f%%" % (accuracy_score(y_test, rfc_cv.predict(X_test)) * 100.0))
print("Best Score: %.2f%%" % (rfc_cv.best_score_ * 100.0))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       460
#            1       1.00      0.98      0.99      2621
#            2       0.73      0.97      0.83        60
#
#     accuracy                           0.98      3141
#    macro avg       0.88      0.98      0.93      3141
# weighted avg       0.98      0.98      0.98      3141
#
#
# Best Hyperparameters:  {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': None}
#
# Accuracy Score: 97.52%
# Best Score: 96.53%

# %% [markdown]
# #### 5.2.2.2) XGBoost Classifier

# %%
params = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.1, 0.01, 0.001],
    'n_estimators': [100, 200, 300],
    'gamma': [0, 0.1, 0.2],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0],
    'reg_alpha': [0, 0.1, 0.5],
    'reg_lambda': [0, 0.1, 0.5]
}
xb_cv = RandomizedSearchCV(xb, param_distributions=params, n_iter=10, cv=5, verbose=3, random_state=42)
xb_cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.902 total time=   1.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.900 total time=   1.6s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.915 total time=   1.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.930 total time=   1.6s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.917 total time=   1.7s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.961 total time=   3.9s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.974 total time=   3.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.968 total time=   3.7s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.974 total time=   3.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.961 total time=   3.6s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.977 total time=   3.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.984 total time=   3.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.979 total time=   3.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.967 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.960 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.971 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.980 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.976 total time=   1.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.909 total time=   1.3s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.907 total time=   1.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.914 total time=   1.3s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.932 total time=   1.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.922 total time=   1.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.937 total time=   1.1s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.936 total time=   1.1s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.940 total time=   1.1s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.967 total time=   1.1s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.951 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.949 total time=   2.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.945 total time=   2.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.960 total time=   2.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.968 total time=   2.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.959 total time=   2.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.952 total time=   2.9s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.943 total time=   2.9s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.956 total time=   2.9s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.968 total time=   2.6s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.958 total time=   2.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.901 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.893 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.911 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.928 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.917 total time=   0.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.967 total time=   1.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.956 total time=   1.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.964 total time=   1.3s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.981 total time=   1.7s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.971 total time=   1.2s
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            callbacks=None, colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, gamma=0, gpu_id=-1,
#                                            grow_policy='depthwise',
#                                            importance_type=None,
#                                            interaction_constraints='',
#                                            learning_rate=0.300000012,
#                                            max_bin=256,...
#                                            n_estimators=100, n_jobs=0,
#                                            num_parallel_tree=1,
#                                            objective='multi:softprob',
#                                            predictor='auto', random_state=0,
#                                            reg_alpha=0, ...),
#                    param_distributions={'colsample_bytree': [0.8, 1.0],
#                                         'gamma': [0, 0.1, 0.2],
#                                         'learning_rate': [0.1, 0.01, 0.001],
#                                         'max_depth': [3, 5, 7],
#                                         'n_estimators': [100, 200, 300],
#                                         'reg_alpha': [0, 0.1, 0.5],
#                                         'reg_lambda': [0, 0.1, 0.5],
#                                         'subsample': [0.8, 1.0]},
#                    random_state=42, verbose=3)

# %%
xb_best_model = xb_cv.best_estimator_
xb_best_model
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.8,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0.2, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=300,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0.5, ...)

# %%
predictions = xb_best_model.predict(X)
predictions
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
# print("Classification Report:\n")
# print(classification_report(y, predictions))
# print("\nBest Hyperparameters: ", xb_cv.best_params_)
# print("Accuracy Score: %.2f%%" % (accuracy_score(y_test, xb_cv.predict(X_test)) * 100.0))
# print("Best Score: %.2f%%" % (xb_cv.best_score_ * 100.0))

print("Classification Report:\n")
print(classification_report(y, predictions))
print("\nBest Hyperparameters: ", xb_cv.best_params_)
print("Accuracy Score: %.2f%%" % (accuracy_score(y_test, xb_cv.predict(X_test)) * 100.0))
print("Best Score: %.2f%%" % (xb_cv.best_score_ * 100.0))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       460
#            1       1.00      0.99      1.00      2621
#            2       0.92      0.98      0.95        60
#
#     accuracy                           0.99      3141
#    macro avg       0.96      0.99      0.98      3141
# weighted avg       0.99      0.99      0.99      3141
#
#
# Best Hyperparameters:  {'subsample': 0.8, 'reg_lambda': 0.1, 'reg_alpha': 0.5, 'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0.2, 'colsample_bytree': 0.8}
# Accuracy Score: 98.22%
# Best Score: 97.49%

# %% [markdown]
# ### 5.2.3) Cross Validation Score after Hyper Parameter Tuning

# %%
rfc_cv_s = cross_val_score(rfc_cv, X, y, cv=5, scoring='accuracy')
xb_cv_s = cross_val_score(xb_cv, X, y, cv=5, scoring='accuracy')
# Print the average accuracy and standard deviation of the scores
print("Accuracy of Random Forest Classifier       : %0.2f (+/- %0.2f)" % (rfc_cv_s.mean(), rfc_cv_s.std() * 2))
print("Accuracy of XGBoost Classifier             : %0.2f (+/- %0.2f)" % (xb_cv_s.mean(), xb_cv_s.std() * 2))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.841 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.827 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.940 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.849 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.730 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.926 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.962 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.964 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.841 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.716 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.934 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.962 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.960 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.841 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.722 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.940 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.962 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.962 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.841 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.831 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.938 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.940 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.853 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.718 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.954 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.956 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.960 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.851 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.765 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.934 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.956 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.960 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.849 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.781 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.928 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.960 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.960 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.841 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.827 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.839 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.761 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.924 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.960 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.958 total time=   0.5s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.537 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.753 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.922 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.940 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.950 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.732 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.932 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.954 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.966 total time=   1.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.952 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.716 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.940 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.958 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.966 total time=   0.9s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.950 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.720 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.948 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.954 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.968 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.841 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.751 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.932 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.940 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.944 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.203 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.728 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.948 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.954 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.962 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.946 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.771 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.928 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.954 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.964 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.950 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.730 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.930 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.954 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.964 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.946 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.753 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.926 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.940 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.944 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.934 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.712 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.928 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.958 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.962 total time=   0.5s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.225 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.746 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.889 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.946 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.956 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.909 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.899 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.958 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.962 total time=   1.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.954 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.893 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.962 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.970 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.954 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.891 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.952 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.960 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.966 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.553 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.742 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.893 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.940 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.946 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.249 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.893 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.885 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.956 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.958 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.934 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.907 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.903 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.958 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.958 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.954 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.905 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.897 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.956 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.956 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.940 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.750 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.891 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.944 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.849 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.938 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.954 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.962 total time=   0.5s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.221 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.865 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.855 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.938 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.940 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.875 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.857 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.942 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.954 total time=   1.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.952 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.871 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.765 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.956 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.950 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.857 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.773 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.952 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.950 total time=   0.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.203 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.867 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.855 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.948 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.167 total time=   0.3s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.875 total time=   0.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.871 total time=   0.3s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.944 total time=   0.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.954 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.934 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.875 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.863 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.948 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.954 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.940 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.875 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.873 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.944 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.956 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.835 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.873 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.855 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.932 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.833 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.748 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.950 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.936 total time=   0.4s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.213 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.861 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.853 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.938 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.189 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.952 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.863 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.732 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.954 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.542 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.956 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.871 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.805 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.948 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.974 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.954 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.867 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.771 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.946 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.974 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.857 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.865 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.855 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.950 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.791 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.169 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.853 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.726 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.964 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.195 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.936 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.865 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.781 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.936 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.189 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.952 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.865 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.730 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.936 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.944 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.557 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.861 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.853 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.938 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.189 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.952 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.833 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.759 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.946 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.966 total time=   0.5s
# Accuracy of Random Forest Classifier       : 0.92 (+/- 0.11)
# Accuracy of XGBoost Classifier             : 0.92 (+/- 0.11)

# %% [markdown]
# # Metric for best Model - XGBoost Classifier

# %% [markdown]
# ## Before Hyperparameter Tuning

# %%
print("Regression Metrics:")
print("Mean Squared Error (MSE)      :",mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error (RMSE):",mean_squared_error(y_test,y_pred, squared=False))
print("Mean Absolute Error (MAE)     :",mean_absolute_error(y_test,y_pred))
print("R-squared Score (R2)          :",r2_score(y_test,y_pred))

print("\nClassification Report:\n",classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n",cm)

print("\nTrain score:", xb.score (X_train, y_train), "\nTest score:",xb.score (X_test, y_test))

print("\nCross Validation Score:")
xb_s = cross_val_score(xb, X, y, cv=5, scoring='accuracy')
print("Accuracy of XGBoost Classifier: %0.2f (+/- %0.2f)" % (xb_s.mean(), xb_s.std() * 2))
print("Accuracy Score : %.5f%%" % (accuracy_score(y_test, xb.predict(X_test)) * 100.0))
print("Precision Score: %.4f%%" % (precision_score(y_test, xb.predict(X_test), average='weighted') * 100.0))
print("Recall Score   : %0.3f%%" % (recall_score(y_test, xb.predict(X_test), average='weighted')*100.0))
print("F1 Score       : %0.2f%%" % (f1_score(y_test, xb.predict(X_test), average='weighted')*100.0))
# Out:
# Regression Metrics:
# Mean Squared Error (MSE)      : 0.01652892561983471
# Root Mean Squared Error (RMSE): 0.128564869306645
# Mean Absolute Error (MAE)     : 0.01652892561983471
# R-squared Score (R2)          : 0.975281347081364
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       518
#            1       0.98      0.97      0.97       521
#            2       0.99      1.00      0.99       534
#
#     accuracy                           0.98      1573
#    macro avg       0.98      0.98      0.98      1573
# weighted avg       0.98      0.98      0.98      1573
#
# Confusion Matrix:
#  [[509   9   0]
#  [ 11 504   6]
#  [  0   0 534]]
#
# Train score: 1.0
# Test score: 0.9834710743801653
#
# Cross Validation Score:
# Accuracy of XGBoost Classifier: 0.90 (+/- 0.13)
# Accuracy Score : 98.34711%
# Precision Score: 98.3451%
# Recall Score   : 98.347%
# F1 Score       : 98.34%

# %% [markdown]
# ## After Hyperparameter Tuning

# %%
print("Regression Metrics:")
print("Mean Squared Error (MSE)      :",mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error (RMSE):",mean_squared_error(y_test,y_pred, squared=False))
print("Mean Absolute Error (MAE)     :",mean_absolute_error(y_test,y_pred))
print("R-squared Score (R2)          :",r2_score(y_test,y_pred))

print("\nClassification Report:\n",classification_report(y_test, y_pred))

cm_cv = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n",cm_cv)

print("\nTrain score:", xb_best_model.score (X_train, y_train), "\nTest score:",xb_cv.score (X_test, y_test),"\n")

xb_cv_s = cross_val_score(xb_cv, X, y, cv=5, scoring='accuracy')
print("\nCross Validation Score:")
print("Accuracy of XGBoost Classifier: %0.2f (+/- %0.2f)" % (xb_cv_s.mean(), xb_cv_s.std() * 2))
print("Accuracy Score : %.5f%%" % (accuracy_score(y_test, xb_cv.predict(X_test)) * 100.0))
print("Precision Score: %.4f%%" % (precision_score(y_test, xb_cv.predict(X_test), average='weighted') * 100.0))
print("Recall Score   : %0.3f%%" % (recall_score(y_test, xb_cv.predict(X_test), average='weighted')*100.0))
print("F1 Score       : %0.2f%%" % (f1_score(y_test, xb_cv.predict(X_test), average='weighted')*100.0))
# Out:
# Regression Metrics:
# Mean Squared Error (MSE)      : 0.01652892561983471
# Root Mean Squared Error (RMSE): 0.128564869306645
# Mean Absolute Error (MAE)     : 0.01652892561983471
# R-squared Score (R2)          : 0.975281347081364
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       518
#            1       0.98      0.97      0.97       521
#            2       0.99      1.00      0.99       534
#
#     accuracy                           0.98      1573
#    macro avg       0.98      0.98      0.98      1573
# weighted avg       0.98      0.98      0.98      1573
#
# Confusion Matrix:
#  [[509   9   0]
#  [ 11 504   6]
#  [  0   0 534]]
#
# Train score: 0.9998410174880763
# Test score: 0.9821996185632549
#
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.841 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.827 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.940 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.849 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.730 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.926 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.962 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.964 total time=   1.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.841 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.716 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.934 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.962 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.960 total time=   1.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.841 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.722 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.940 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.962 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.962 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.841 total time=   0.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.831 total time=   0.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.938 total time=   0.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.940 total time=   0.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.853 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.718 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.954 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.956 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.960 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.851 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.765 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.934 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.956 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.960 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.849 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.781 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.928 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.960 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.960 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.841 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.827 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.839 total time=   0.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.761 total time=   0.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.924 total time=   0.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.960 total time=   0.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.958 total time=   0.6s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.537 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.753 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.922 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.940 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.950 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.732 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.932 total time=   1.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.954 total time=   1.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.966 total time=   1.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.952 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.716 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.940 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.958 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.966 total time=   1.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.950 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.720 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.948 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.954 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.968 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.841 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.751 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.932 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.940 total time=   0.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.944 total time=   0.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.203 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.728 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.948 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.954 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.962 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.946 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.771 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.928 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.954 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.964 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.950 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.730 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.930 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.954 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.964 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.946 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.753 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.926 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.940 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.944 total time=   0.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.934 total time=   0.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.712 total time=   0.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.928 total time=   0.7s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.958 total time=   0.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.962 total time=   0.6s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.225 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.746 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.889 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.946 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.956 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.909 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.899 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.958 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.962 total time=   1.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.954 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.893 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.962 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.970 total time=   1.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.954 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.891 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.952 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.960 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.966 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.553 total time=   0.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.742 total time=   0.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.893 total time=   0.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.940 total time=   0.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.946 total time=   0.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.249 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.893 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.885 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.956 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.958 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.934 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.907 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.903 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.958 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.958 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.954 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.905 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.897 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.956 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.956 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.940 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.750 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.891 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.944 total time=   0.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.849 total time=   0.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.938 total time=   0.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.954 total time=   0.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.962 total time=   0.5s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.221 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.865 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.855 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.938 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.940 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.875 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.857 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.942 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.954 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.952 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.871 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.765 total time=   1.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.956 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.942 total time=   1.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.950 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.857 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.773 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.952 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.950 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.203 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.867 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.855 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.948 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.167 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.875 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.871 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.944 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.954 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.934 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.875 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.863 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.948 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.954 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.940 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.875 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.873 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.944 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.956 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.835 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.873 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.855 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.942 total time=   0.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.932 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.833 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.748 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.950 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.936 total time=   0.6s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.213 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.861 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.853 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.938 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.189 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.952 total time=   1.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.863 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.732 total time=   1.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.954 total time=   1.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.542 total time=   1.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.956 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.871 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.805 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.948 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.974 total time=   1.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.954 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.867 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.771 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.946 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=7, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=1.0;, score=0.974 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.857 total time=   0.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.865 total time=   0.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.855 total time=   0.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.950 total time=   0.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8;, score=0.791 total time=   0.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.169 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.853 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.726 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.964 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0;, score=0.195 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.936 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.865 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.781 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.936 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=7, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8;, score=0.189 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.952 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.865 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.730 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.936 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.1, subsample=0.8;, score=0.944 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.557 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.861 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.853 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.938 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.001, max_depth=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.189 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.952 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.833 total time=   0.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.759 total time=   0.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.946 total time=   0.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8;, score=0.966 total time=   0.6s
#
# Cross Validation Score:
# Accuracy of XGBoost Classifier: 0.92 (+/- 0.11)
# Accuracy Score : 98.21996%
# Precision Score: 98.2171%
# Recall Score   : 98.220%
# F1 Score       : 98.22%

# %% [markdown]
# # 6) Model Deployment

# %%
wml_credentials = {
    "url":"https://us-south.ml.cloud.ibm.com",
    "apikey":"BTuxA4iTj2hEcEcq77RHBr_0XTi3cyrn2XgvQN_3t8RU"
}

# %%
client = APIClient(wml_credentials)

# %%
metadata = {
    client.spaces.ConfigurationMetaNames.NAME:"Cancer Space",
    client.spaces.ConfigurationMetaNames.DESCRIPTION:"To Predict Cancer Mortality & Incidence Rates",
    client.spaces.ConfigurationMetaNames.STORAGE:{
        "type":"Cloud Object Storage-fl",
        "resource_crn":"crn:v1:bluemix:public:cloud-object-storage:global:a/534cee66b3344f93908f5faddd2ea1b2:43e1b386-c0dc-4fff-bd94-70a87180d9b3::"
    },
    client.spaces.ConfigurationMetaNames.COMPUTE:{
        "name":"Watson Machine Learning-qa",
        "crn":"crn:v1:bluemix:public:pm-20:us-south:a/534cee66b3344f93908f5faddd2ea1b2:7faac8f8-0242-493f-8340-1b1338dede58::"
    } 
}

# %%
space_details = client.spaces.store(meta_props=metadata)
# Out:
# Space has been created. However some background setup activities might still be on-going. Check for 'status' field in the response. It has to show 'active' before space can be used. If it's not 'active', you can monitor the state with a call to spaces.get_details(space_id). Alternatively, use background_mode=False when calling client.spaces.store().

# %%
space_details
# Out:
# {'entity': {'compute': [{'crn': 'crn:v1:bluemix:public:pm-20:us-south:a/534cee66b3344f93908f5faddd2ea1b2:7faac8f8-0242-493f-8340-1b1338dede58::',
#     'guid': '7faac8f8-0242-493f-8340-1b1338dede58',
#     'name': 'Watson Machine Learning-qa',
#     'type': 'machine_learning'}],
#   'description': 'To Predict Cancer Mortality & Incidence Rates',
#   'members': [{'id': 'IBMid-6670010PV5',
#     'role': 'admin',
#     'state': 'active',
#     'type': 'user'}],
#   'name': 'Cancer Space',
#   'scope': {'bss_account_id': '534cee66b3344f93908f5faddd2ea1b2'},
#   'stage': {'production': False},
#   'status': {'state': 'preparing'}},
#  'metadata': {'created_at': '2023-05-19T04:17:04.767Z',
#   'creator_id': 'IBMid-6670010PV5',
#   'id': 'c8fcb217-7ff9-40b8-b334-f1087f15be1e',
#   'url': '/v2/spaces/c8fcb217-7ff9-40b8-b334-f1087f15be1e'}}

# %%
space_id = space_details['metadata']['id']
space_id
# Out:
# 'c8fcb217-7ff9-40b8-b334-f1087f15be1e'

# %%
client.set.default_space(space_id)
# Out:
# 'SUCCESS'

# %%
client.software_specifications.list(100)
# Out:
# -------------------------------  ------------------------------------  ----  ------------------  --------------------------
# NAME                             ID                                    TYPE  STATE               REPLACEMENT
# default_py3.6                    0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base  unsupported         runtime-22.2-py3.10
# autoai-ts_rt23.1-py3.10          01ce9391-1a79-5a33-94fb-2e134337f314  base  not_provided
# kernel-spark3.2-scala2.12        020d69ce-7ac1-5e68-ac1a-31189867356a  base  not_provided
# pytorch-onnx_1.3-py3.7-edt       069ea134-3346-5748-b513-49120e15d288  base  not_provided
# tensorflow_rt23.1-py3.10         079a91e0-245f-5269-8926-3c20b28f37dc  base  not_provided
# scikit-learn_0.20-py3.6          09c5a1d0-9c1e-4473-a344-eb7b665ff687  base  unsupported         runtime-22.2-py3.10
# spark-mllib_3.0-scala_2.12       09f4cff0-90a7-5899-b9ed-1ef348aebdee  base  unsupported
# pytorch-onnx_rt22.1-py3.9        0b848dd4-e681-5599-be41-b5f6fccc6471  base  create-unsupported  pytorch-onnx_rt22.2-py3.10
# ai-function_0.1-py3.6            0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base  unsupported         runtime-22.2-py3.10
# shiny-r3.6                       0e6e79df-875e-4f24-8ae9-62dcc2148306  base  not_provided
# tensorflow_2.4-py3.7-horovod     1092590a-307d-563d-9b62-4eb7d64b3f22  base  unsupported         tensorflow_rt22.2-py3.10
# pytorch_1.1-py3.6                10ac12d6-6b30-4ccd-8392-3e922c096a92  base  unsupported
# tensorflow_1.15-py3.6-ddl        111e41b3-de2d-5422-a4d6-bf776828c4b7  base  unsupported
# autoai-kb_rt22.2-py3.10          125b6d9a-5b1f-5e8d-972a-b251688ccf40  base  supported
# runtime-22.1-py3.9               12b83a17-24d8-5082-900f-0ab31fbfd3cb  base  create-unsupported  runtime-22.2-py3.10
# scikit-learn_0.22-py3.6          154010fa-5b3b-4ac1-82af-4d5ee5abbc85  base  unsupported         runtime-22.2-py3.10
# pytorch-onnx_rt23.1-py3.10       195067e6-4c5e-5fab-8bd0-e7623a88b4d3  base  not_provided
# default_r3.6                     1b70aec3-ab34-4b87-8aa0-a4a3c8296a36  base  deprecated
# pytorch-onnx_1.3-py3.6           1bc6029a-cc97-56da-b8e0-39c3880dbbe7  base  unsupported         runtime-22.2-py3.10
# kernel-spark3.3-r3.6             1c9e5454-f216-59dd-a20e-474a5cdf5988  base  not_provided
# tensorflow_2.1-py3.6             1eb25b84-d6ed-5dde-b6a5-3fbdf1665666  base  unsupported         runtime-22.2-py3.10
# spark-mllib_3.2                  20047f72-0a98-58c7-9ff5-a77b012eb8f5  base  unsupported         spark-mllib_3.3
# tensorflow_2.4-py3.8-horovod     217c16f6-178f-56bf-824a-b19f20564c49  base  unsupported         tensorflow_rt22.2-py3.10
# runtime-22.1-py3.9-cuda          26215f05-08c3-5a41-a1b0-da66306ce658  base  create-unsupported  runtime-22.2-py3.10-cuda
# do_py3.8                         295addb5-9ef9-547e-9bf4-92ae3563e720  base  not_provided
# autoai-ts_3.8-py3.8              2aa0c932-798f-5ae9-abd6-15e0c2402fb5  base  unsupported         autoai-ts_rt22.2-py3.10
# tensorflow_1.15-py3.6            2b73a275-7cbf-420b-a912-eae7f436e0bc  base  unsupported         runtime-22.2-py3.10
# kernel-spark3.3-py3.9            2b7961e2-e3b1-5a8c-a491-482c8368839a  base  not_provided
# pytorch_1.2-py3.6                2c8ef57d-2687-4b7d-acce-01f94976dac1  base  unsupported         runtime-22.2-py3.10
# spark-mllib_2.3                  2e51f700-bca0-4b0d-88dc-5c6791338875  base  create-unsupported  spark-mllib_3.3
# pytorch-onnx_1.1-py3.6-edt       32983cea-3f32-4400-8965-dde874a8d67e  base  unsupported
# spark-mllib_3.0-py37             36507ebe-8770-55ba-ab2a-eafe787600e9  base  unsupported         spark-mllib_3.3
# spark-mllib_2.4                  390d21f8-e58b-4fac-9c55-d7ceda621326  base  unsupported         spark-mllib_3.3
# autoai-ts_rt22.2-py3.10          396b2e83-0953-5b86-9a55-7ce1628a406f  base  supported
# xgboost_0.82-py3.6               39e31acd-5f30-41dc-ae44-60233c80306e  base  unsupported         runtime-22.2-py3.10
# pytorch-onnx_1.2-py3.6-edt       40589d0e-7019-4e28-8daa-fb03b6f4fe12  base  unsupported
# pytorch-onnx_rt22.2-py3.10       40e73f55-783a-5535-b3fa-0c8b94291431  base  supported
# default_r36py38                  41c247d3-45f8-5a71-b065-8580229facf0  base  not_provided
# autoai-ts_rt22.1-py3.9           4269d26e-07ba-5d40-8f66-2d495b0c71f7  base  create-unsupported  autoai-ts_rt22.2-py3.10
# autoai-obm_3.0                   42b92e18-d9ab-567f-988a-4240ba1ed5f7  base  unsupported         autoai-obm_3.2
# pmml-3.0_4.3                     493bcb95-16f1-5bc5-bee8-81b8af80e9c7  base  supported
# spark-mllib_2.4-r_3.6            49403dff-92e9-4c87-a3d7-a42d0021c095  base  unsupported         spark-mllib_3.3
# xgboost_0.90-py3.6               4ff8d6c2-1343-4c18-85e1-689c965304d3  base  unsupported         runtime-22.2-py3.10
# pytorch-onnx_1.1-py3.6           50f95b2a-bc16-43bb-bc94-b0bed208c60b  base  unsupported         runtime-22.2-py3.10
# autoai-ts_3.9-py3.8              52c57136-80fa-572e-8728-a5e7cbb42cde  base  unsupported         autoai-ts_rt22.2-py3.10
# spark-mllib_2.4-scala_2.11       55a70f99-7320-4be5-9fb9-9edb5a443af5  base  unsupported         spark-mllib_3.3
# spark-mllib_3.0                  5c1b0ca2-4977-5c2e-9439-ffd44ea8ffe9  base  unsupported         spark-mllib_3.3
# autoai-obm_2.0                   5c2e37fa-80b8-5e77-840f-d912469614ee  base  unsupported         autoai-obm_3.2
# spss-modeler_18.1                5c3cad7e-507f-4b2a-a9a3-ab53a21dee8b  base  supported
# cuda-py3.8                       5d3232bf-c86b-5df4-a2cd-7bb870a1cd4e  base  not_provided
# runtime-22.2-py3.10-xc           5e8cddff-db4a-5a6a-b8aa-2d4af9864dab  base  supported
# autoai-kb_3.1-py3.7              632d4b22-10aa-5180-88f0-f52dfb6444d7  base  unsupported         autoai-kb_rt22.2-py3.10
# pytorch-onnx_1.7-py3.8           634d3cdc-b562-5bf9-a2d4-ea90a478456b  base  unsupported         pytorch-onnx_rt22.2-py3.10
# kernel-spark3.3-r4.2             65691379-8334-5b81-9d22-a9b77b3c2f8b  base  not_provided
# spark-mllib_2.3-r_3.6            6586b9e3-ccd6-4f92-900f-0f8cb2bd6f0c  base  not_provided
# tensorflow_2.4-py3.7             65e171d7-72d1-55d9-8ebb-f813d620c9bb  base  unsupported         tensorflow_rt22.2-py3.10
# spss-modeler_18.2                687eddc9-028a-4117-b9dd-e57b36f1efa5  base  supported
# pytorch-onnx_1.2-py3.6           692a6a4d-2c4d-45ff-a1ed-b167ee55469a  base  unsupported         runtime-22.2-py3.10
# spark-mllib_2.3-scala_2.11       7963efe5-bbec-417e-92cf-0574e21b4e8d  base  not_provided
# spark-mllib_2.4-py37             7abc992b-b685-532b-a122-a396a3cdbaab  base  unsupported         spark-mllib_3.3
# caffe_1.0-py3.6                  7bb3dbe2-da6e-4145-918d-b6d84aa93b6b  base  unsupported
# pytorch-onnx_1.7-py3.7           812c6631-42b7-5613-982b-02098e6c909c  base  unsupported         pytorch-onnx_rt22.2-py3.10
# cuda-py3.6                       82c79ece-4d12-40e6-8787-a7b9e0f62770  base  unsupported
# tensorflow_1.15-py3.6-horovod    8964680e-d5e4-5bb8-919b-8342c6c0dfd8  base  unsupported
# hybrid_0.1                       8c1a58c6-62b5-4dc4-987a-df751c2756b6  base  supported
# pytorch-onnx_1.3-py3.7           8d5d8a87-a912-54cf-81ec-3914adaa988d  base  not_provided
# caffe-ibm_1.0-py3.6              8d863266-7927-4d1e-97d7-56a7f4c0a19b  base  unsupported
# runtime-22.2-py3.10-cuda         8ef391e4-ef58-5d46-b078-a82c211c1058  base  supported
# spss-modeler_17.1                902d0051-84bd-4af6-ab6b-8f6aa6fdeabb  base  supported
# do_12.10                         9100fd72-8159-4eb9-8a0b-a87e12eefa36  base  unsupported         do_20.1
# do_py3.7                         9447fa8b-2051-4d24-9eef-5acb0e3c59f8  base  not_provided
# spark-mllib_3.0-r_3.6            94bb6052-c837-589d-83f1-f4142f219e32  base  unsupported
# cuda-py3.7-opence                94e9652b-7f2d-59d5-ba5a-23a414ea488f  base  not_provided
# nlp-py3.8                        96e60351-99d4-5a1c-9cc0-473ac1b5a864  base  not_provided
# cuda-py3.7                       9a44990c-1aa1-4c7d-baf8-c4099011741c  base  not_provided
# hybrid_0.2                       9b3f9040-9cee-4ead-8d7a-780600f542f7  base  supported
# spark-mllib_3.0-py38             9f7a8fc1-4d3c-5e65-ab90-41fa8de2d418  base  unsupported         spark-mllib_3.3
# autoai-tsad_rt22.2-py3.10        a1380ce0-5d3c-59ca-9b44-d6bf0739838a  base  supported
# autoai-kb_3.3-py3.7              a545cca3-02df-5c61-9e88-998b09dc79af  base  unsupported         autoai-kb_rt22.2-py3.10
# spark-mllib_3.0-py39             a6082a27-5acc-5163-b02c-6b96916eb5e0  base  unsupported         spark-mllib_3.3
# runtime-22.1-py3.9-do            a7e7dbf1-1d03-5544-994d-e5ec845ce99a  base  not_provided
# default_py3.8                    ab9e1b80-f2ce-592c-a7d2-4f2344f77194  base  unsupported         runtime-22.2-py3.10
# tensorflow_rt22.1-py3.9          acd9c798-6974-5d2f-a657-ce06e986df4d  base  create-unsupported  tensorflow_rt22.2-py3.10
# kernel-spark3.2-py3.9            ad7033ee-794e-58cf-812e-a95f4b64b207  base  not_provided
# autoai-obm_2.0 with Spark 3.0    af10f35f-69fa-5d66-9bf5-acb58434263a  base  unsupported         autoai-obm_3.2
# autoai-kb_rt23.1-py3.10          b4246d87-d8b3-5621-9fea-76a8ea452616  base  not_provided
# runtime-22.2-py3.10              b56101f1-309d-549b-a849-eaa63f77b2fb  base  supported
# default_py3.7_opence             c2057dd4-f42c-5f77-a02f-72bdbd3282c9  base  unsupported         runtime-22.2-py3.10
# tensorflow_2.1-py3.7             c4032338-2a40-500a-beef-b01ab2667e27  base  unsupported         pytorch-onnx_rt22.2-py3.10
# do_py3.7_opence                  cc8f8976-b74a-551a-bb66-6377f8d865b4  base  not_provided
# autoai-tsad_rt23.1-py3.10        cd3c730f-bc13-594f-9510-002634662e8b  base  not_provided
# spark-mllib_3.3                  d11f2434-4fc7-58b7-8a62-755da64fdaf8  base  supported
# autoai-kb_3.0-py3.6              d139f196-e04b-5d8b-9140-9a10ca1fa91a  base  unsupported         autoai-kb_rt22.2-py3.10
# spark-mllib_3.0-py36             d82546d5-dd78-5fbb-9131-2ec309bc56ed  base  unsupported         spark-mllib_3.3
# autoai-kb_3.4-py3.8              da9b39c3-758c-5a4f-9cfd-457dd4d8c395  base  unsupported         autoai-kb_rt22.2-py3.10
# kernel-spark3.2-r3.6             db2fe4d6-d641-5d05-9972-73c654c60e0a  base  not_provided
# autoai-kb_rt22.1-py3.9           db6afe93-665f-5910-b117-d879897404d9  base  create-unsupported  autoai-kb_rt22.2-py3.10
# tensorflow_rt22.1-py3.9-horovod  dda170cc-ca67-5da7-9b7a-cf84c6987fae  base  create-unsupported  tensorflow_rt22.2-py3.10
# autoai-ts_1.0-py3.7              deef04f0-0c42-5147-9711-89f9904299db  base  unsupported         autoai-ts_rt22.2-py3.10
# tensorflow_2.1-py3.7-horovod     e384fce5-fdd1-53f8-bc71-11326c9c635f  base  unsupported         tensorflow_rt22.2-py3.10
# -------------------------------  ------------------------------------  ----  ------------------  --------------------------
#                                NAME                                    ID  \
# 0                     default_py3.6  0062b8c9-8b7d-44a0-a9b9-46c416adcbd9
# 1           autoai-ts_rt23.1-py3.10  01ce9391-1a79-5a33-94fb-2e134337f314
# 2         kernel-spark3.2-scala2.12  020d69ce-7ac1-5e68-ac1a-31189867356a
# 3        pytorch-onnx_1.3-py3.7-edt  069ea134-3346-5748-b513-49120e15d288
# 4          tensorflow_rt23.1-py3.10  079a91e0-245f-5269-8926-3c20b28f37dc
# ..                              ...                                   ...
# 95             kernel-spark3.2-r3.6  db2fe4d6-d641-5d05-9972-73c654c60e0a
# 96           autoai-kb_rt22.1-py3.9  db6afe93-665f-5910-b117-d879897404d9
# 97  tensorflow_rt22.1-py3.9-horovod  dda170cc-ca67-5da7-9b7a-cf84c6987fae
# 98              autoai-ts_1.0-py3.7  deef04f0-0c42-5147-9711-89f9904299db
# 99     tensorflow_2.1-py3.7-horovod  e384fce5-fdd1-53f8-bc71-11326c9c635f
#
#     TYPE               STATE               REPLACEMENT
# 0   base         unsupported       runtime-22.2-py3.10
# 1   base        not_provided
# 2   base        not_provided
# 3   base        not_provided
# 4   base        not_provided
# ..   ...                 ...                       ...
# 95  base        not_provided
# 96  base  create-unsupported   autoai-kb_rt22.2-py3.10
# 97  base  create-unsupported  tensorflow_rt22.2-py3.10
# 98  base         unsupported   autoai-ts_rt22.2-py3.10
# 99  base         unsupported  tensorflow_rt22.2-py3.10
#
# [100 rows x 5 columns]

# %%
xgb.__version__
# Out:
# '1.6.2'

# %%
spec_id = client.software_specifications.get_id_by_name('runtime-22.2-py3.10')
spec_id
# Out:
# 'b56101f1-309d-549b-a849-eaa63f77b2fb'

# %%
model_details=client.repository.store_model(model=xb_cv, meta_props={
    client.repository.ModelMetaNames.NAME:"Cancer Prediction",
    client.repository.ModelMetaNames.SOFTWARE_SPEC_UID:spec_id,
    client.repository.ModelMetaNames.TYPE:"scikit-learn_1.1"
})

# %%
model_details
# Out:
# {'entity': {'hybrid_pipeline_software_specs': [],
#   'software_spec': {'id': 'b56101f1-309d-549b-a849-eaa63f77b2fb',
#    'name': 'runtime-22.2-py3.10'},
#   'type': 'scikit-learn_1.1'},
#  'metadata': {'created_at': '2023-05-19T04:24:18.462Z',
#   'id': '99c4ab19-6b16-49aa-bf4a-99f4ccfbe146',
#   'modified_at': '2023-05-19T04:24:22.608Z',
#   'name': 'Cancer Prediction',
#   'owner': 'IBMid-6670010PV5',
#   'resource_key': 'c69ebb0d-b2a5-47c3-baa1-bad50ce1a97d',
#   'space_id': 'c8fcb217-7ff9-40b8-b334-f1087f15be1e'},
#  'system': {'warnings': []}}

# %%
model_id = model_details['metadata']['id']

# %%
metadata = {
    client.deployments.ConfigurationMetaNames.NAME:"Cancer Deployment",
    client.deployments.ConfigurationMetaNames.ONLINE:{}
}

# %%
deployment_details = client.deployments.create(artifact_uid=model_id,meta_props=metadata)
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: '99c4ab19-6b16-49aa-bf4a-99f4ccfbe146' started
#
# #######################################################################################
#
#
# initializing
# Note: online_url is deprecated and will be removed in a future release. Use serving_urls instead.
#
# ready
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='da9d100a-259e-4aa5-82e2-8901b63066a1'
# ------------------------------------------------------------------------------------------------

# %%
deployment_id=deployment_details['metadata']['id']

# %%
payload = {
    client.deployments.ScoringMetaNames.INPUT_DATA:[{
        "fields":['FIPS','Age-Adjusted Incidence Rate(Ê) - cases per 100,000','Lower 95% Confidence Interval','Upper 95% Confidence Interval','Average Annual Count','Recent 5-Year Trend (ˆ) in Incidence Rates','Lower 95% Confidence Interval.1','Upper 95% Confidence Interval.1'],
        "values":[[1001,74.9,65.1,85.7,43,40.6,54.1,30.7]]
    }]
}

# %%
predictions=client.deployments.score(deployment_id=deployment_id,meta_props=payload)

# %%
predictions['predictions'][0]['values'][0][0]
# Out:
# 1
